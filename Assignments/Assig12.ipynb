# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("../Datasets/iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
features=df.columns
features
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
feature_types=df.dtypes
feature_types
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
for feature in features:
    # print("\n--------- ",feature," -----------\n")
    plt.figure(figsize=(8,6))
    plt.hist(df[feature].values,alpha=0.7)
    plt.xlabel(feature)
    plt.ylabel("frequency")
    plt.title("Histogram for "+feature)
    plt.show()

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
df2=df.drop('Id',axis=1)
df2.boxplot(figsize=(10,10))
# Out:
# <Axes: >

# %%
Q1_sepal=df["SepalLengthCm"].quantile(0.25)
Q3_sepal=df["SepalLengthCm"].quantile(0.75)
IQR=Q3_sepal-Q1_sepal
IQR
# Out:
# 1.3000000000000007
