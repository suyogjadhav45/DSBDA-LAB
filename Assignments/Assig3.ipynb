# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("../Datasets/Titanic-Dataset.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 886          887         0       2                     Montvila, Rev. Juozas  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.ndim
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#can be done like this also
#meanAge=np.mean(df["Age"])
#df["Age"].fillna(meanAge,inplace=True)

#method 2
df["Age"].fillna(df["Age"].mean(),inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age
# 0                              Braund, Mr. Owen Harris    male  22.000000  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin",inplace=True,axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age
# 0                              Braund, Mr. Owen Harris    male  22.000000  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
EmbarkedData=df["Embarked"].unique()
EmbarkedData
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].fillna(df['Embarked'].mode().iloc[0],inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age
# 0                              Braund, Mr. Owen Harris    male  22.000000  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
EmbarkedData=df["Embarked"].unique()
EmbarkedData
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sns.distplot(df["Fare"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17216\1092105540.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fare"])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
FareRemoveSkew=np.sqrt(df["Fare"])
FareRemoveSkew
# Out:
# 0      2.692582
# 1      8.442944
# 2      2.815138
# 3      7.286975
# 4      2.837252
#          ...
# 886    3.605551
# 887    5.477226
# 888    4.842520
# 889    5.477226
# 890    2.783882
# Name: Fare, Length: 891, dtype: float64

# %%
sns.distplot(FareRemoveSkew)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17216\905964446.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(FareRemoveSkew)
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
from scipy import stats
epsilon=np.finfo(float).eps
df["Fare"]=df["Fare"]+epsilon
df["Fare"]=stats.boxcox(df["Fare"])[0]
pd.Series(df["Fare"]).skew()
# Out:
# 0.04012479606688069

# %%
sns.distplot(df["Fare"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17216\1092105540.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fare"])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
FareData=df["Fare"].unique()
FareData.sort()
FareData
# Out:
# array([-4.65776819,  1.61877405,  1.92234204,  2.24224343,  2.28914959,
#         2.29204302,  2.30260708,  2.36019915,  2.38421927,  2.40432583,
#         2.40977128,  2.42511004,  2.42601616,  2.42692185,  2.44212588,
#         2.44569483,  2.4633996 ,  2.46428802,  2.46868187,  2.48182523,
#         2.51986985,  2.5250019 ,  2.5309792 ,  2.54710068,  2.55131281,
#         2.56642645,  2.5672694 ,  2.56809193,  2.56893417,  2.56977605,
#         2.57143872,  2.5764383 ,  2.57893336,  2.58058835,  2.58142528,
#         2.5872342 ,  2.59219408,  2.59631127,  2.59714159,  2.59878143,
#         2.60041992,  2.60617351,  2.62657041,  2.63061704,  2.64272717,
#         2.64755072,  2.65155504,  2.6786232 ,  2.69044699,  2.69829728,
#         2.70375743,  2.70843648,  2.71932457,  2.74473037,  2.74625378,
#         2.75006646,  2.75540679,  2.78036658,  2.80725046,  2.84547396,
#         2.8469239 ,  2.86863731,  2.89012391,  2.89154272,  2.89439449,
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age
# 0                              Braund, Mr. Owen Harris    male  22.000000  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
transformed_data=scaler.fit_transform(df)
transformed_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17216\625665858.py in ?()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler=StandardScaler()
# ----> 3 transformed_data=scaler.fit_transform(df)
#       4 transformed_data
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
# ...
