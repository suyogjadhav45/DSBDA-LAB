# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../Datasets/Netflix.csv")

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.ndim
# Out:
# 2

# %%
df.head(10)
# Out:
#   show_id     type                                      title
# 0      s1  TV Show                                         3%  \
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
# 5   s1002    Movie                                  Blue Ruin
# 6   s1003    Movie                                Blue Streak
# 7   s1004    Movie                             Blue Valentine
# 8   s1005    Movie                               BluffMaster!
# 9   s1006    Movie        Blurred Lines: Inside the Art World
#
#            director                                               cast
# 0               NaN  João Miguel, Bianca Comparato, Michel Gomes, R...  \
# 1      Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# ...

# %%
df.tail()
# Out:
#      show_id     type                      title             director
# 7782    s995  TV Show                 Blown Away                  NaN  \
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast
# 7782                                                NaN  \
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration
# 7782                  Canada  12-Jul-19          2019  TV-14         1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
df
# Out:
#      show_id     type                                      title
# 0         s1  TV Show                                         3%  \
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#      show_id   type                                      title
# 1        s10  Movie                                       1920  \
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director
# 1                   Vikram Bhatt  \
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...

# %%
df.shape
# Out:
# (4808, 12)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %%
df["duration"]=df["duration"].astype("float")

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration        float64
# genres           object
# description      object
# dtype: object

# %%
# Out:
#       Movie  TV Show
# 1      True    False
# 2      True    False
# 3      True    False
# 5      True    False
# 6      True    False
# ...     ...      ...
# 7778   True    False
# 7781   True    False
# 7784   True    False
# 7785   True    False
# 7786   True    False
#
# [4808 rows x 2 columns]

# %%
#for categorical variables into quantitive variables
newdf=pd.get_dummies(df["type"])
newdf
# Out:
#       Movie  TV Show
# 1      True    False
# 2      True    False
# 3      True    False
# 5      True    False
# 6      True    False
# ...     ...      ...
# 7778   True    False
# 7781   True    False
# 7784   True    False
# 7785   True    False
# 7786   True    False
#
# [4808 rows x 2 columns]

# %%
dfconcat=pd.concat([df,newdf],axis=1)
dfconcat
# Out:
#      show_id   type                                      title
# 1        s10  Movie                                       1920  \
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director
# 1                   Vikram Bhatt  \
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...

# %%
#for categorical variables into quantitive variables
dflabel=df.copy()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
dflabel["type"]=label_encoder.fit_transform(dflabel["type"])

# %%
df
# Out:
#      show_id   type                                      title
# 1        s10  Movie                                       1920  \
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director
# 1                   Vikram Bhatt  \
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...

# %%
dflabel
# Out:
#      show_id  type                                      title
# 1        s10     0                                       1920  \
# 2       s100     0                                 3 Heroines
# 3      s1000     0  Blue Mountain State: The Rise of Thadland
# 5      s1002     0                                  Blue Ruin
# 6      s1003     0                                Blue Streak
# ...      ...   ...                                        ...
# 7778    s991     0                            Blood Will Tell
# 7781    s994     0                                       Blow
# 7784    s997     0                  Blue Is the Warmest Color
# 7785    s998     0                               Blue Jasmine
# 7786    s999     0                                   Blue Jay
#
#                         director
# 1                   Vikram Bhatt  \
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...
