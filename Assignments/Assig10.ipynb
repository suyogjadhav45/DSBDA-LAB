# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from nltk import pos_tag

# %%
import nltk
# nltk.download('punkt')

# %%
with open("../Datasets/file1.txt","r") as file:
    doc1=file.read()
doc1
# Out:
# "The sun sets in the west, casting a warm glow across the horizon. Birds chirp happily in the trees, creating a melodious symphony. The smell of freshly brewed coffee fills the air, awakening the senses. People walk briskly on the bustling streets, immersed in their own thoughts. Children play in the park, their laughter echoing through the open space.\n\nA gentle breeze rustles the leaves, bringing relief from the summer heat. A rainbow appears after the rain, painting the sky with vibrant colors. The waves crash against the shore, creating a soothing rhythm. The aroma of freshly baked bread wafts from the nearby bakery, tempting passersby. Friends gather around a bonfire, sharing stories and laughter late into the night.\n\nThe city comes alive with lights as night falls, creating a magical atmosphere. Stars twinkle in the clear night sky, inspiring dreams and wonder. The scent of blooming flowers fills the garden, attracting bees and butterflies. A couple walks hand in hand along a moonlit path, enjoying each other's company.\n\nLife is a beautiful journey, filled with moments of joy, love, and adventure. Every day brings new opportunities and experiences to cherish. Embrace the beauty of the world and find happiness in the simple pleasures that surround you.\n\n"

# %%
with open("../Datasets/file2.txt","r") as file:
    doc2=file.read()
doc2
# Out:
# 'The gentle breeze rustles through the leaves, creating a soothing melody. Birds chirp in the distance, their melodic songs filling the air. A field of colorful wildflowers sways gracefully in the wind, painting the landscape with vibrant hues. The sun shines brightly, casting its warm rays upon the earth.\n\nIn a quaint little cafe, the aroma of freshly brewed coffee fills the air, enticing passersby. Baristas skillfully craft intricate latte art, turning coffee into a work of art. The sound of friendly chatter and laughter echoes throughout the cozy space. Patrons savor each sip, enjoying moments of relaxation.\n\nOn a sandy beach, waves crash against the shore, creating a symphony of sounds. Children build sandcastles, their laughter filling the air with joy. Seagulls soar overhead, their graceful flight against the blue sky mesmerizing to watch. Beachgoers bask in the sun, enjoying the warmth on their skin.\n\nIn a bustling market, vendors display their colorful array of fruits and vegetables. The scent of spices wafts through the air, tempting taste buds. Bargaining and lively conversations fill the atmosphere, creating a lively and vibrant ambiance. The market is a hub of activity and a feast for the senses.\n\nAs night falls, stars twinkle in the velvety sky, illuminating the world with their celestial glow. The moon casts a gentle light, creating a romantic atmosphere. Fireflies dance among the trees, their soft glow adding a touch of magic to the night. Night owls hoot in the distance, while crickets serenade the darkness.\n\nLife is a beautiful journey, filled with moments of wonder and awe. From the tranquility of nature to the energy of bustling cities, every experience holds its own charm. Embrace the diversity and beauty that surrounds you, and let each day be an adventure worth cherishing.\n\n\n'

# %%
with open("../Datasets/file3.txt","r") as file:
    doc3=file.read()
doc3
# Out:
# 'The majestic mountains rise tall against the clear blue sky, their peaks capped with snow. The sound of a babbling brook fills the air, as it weaves its way through the lush green valley. A deer gracefully leaps across the meadow, its coat shimmering in the sunlight. The scent of pine trees permeates the forest, creating a refreshing aroma.\n\nIn a cozy cottage nestled by the lakeside, a crackling fireplace warms the room. The soft glow of candlelight illuminates the space, creating a peaceful ambiance. The aroma of freshly baked apple pie fills the kitchen, enticing everyone with its delicious scent. Family and friends gather around the table, sharing laughter and stories.\n\nAs the sun sets, painting the sky with hues of orange and pink, a sense of tranquility settles over the landscape. The stars twinkle brightly, creating a breathtaking canopy in the night sky. The moon casts a gentle glow, guiding the way for nocturnal creatures. Owls hoot in the distance, adding to the mystique of the night.\n\nIn the city, bustling streets are filled with the rhythm of life. Neon lights illuminate the skyline, creating a vibrant display. People hurry along, immersed in their own worlds, while street performers captivate audiences with their talents. The aroma of diverse cuisines fills the air, tempting taste buds with a culinary adventure.\n\nLife is a tapestry of experiences, each thread woven with moments of joy, love, and discovery. From serene natural landscapes to vibrant urban landscapes, every corner of the world offers its own unique beauty. Embrace the wonders that surround you and let the journey unfold, filled with remarkable encounters and cherished memories.\n\n'

# %%
docs=[doc1,doc2,doc3]

# %%
tokens={}
i=0;
for doc in docs:
    tokens[i]=word_tokenize(doc)
    i=i+1

# %%
print(tokens[0])
# Out:
# ['The', 'sun', 'sets', 'in', 'the', 'west', ',', 'casting', 'a', 'warm', 'glow', 'across', 'the', 'horizon', '.', 'Birds', 'chirp', 'happily', 'in', 'the', 'trees', ',', 'creating', 'a', 'melodious', 'symphony', '.', 'The', 'smell', 'of', 'freshly', 'brewed', 'coffee', 'fills', 'the', 'air', ',', 'awakening', 'the', 'senses', '.', 'People', 'walk', 'briskly', 'on', 'the', 'bustling', 'streets', ',', 'immersed', 'in', 'their', 'own', 'thoughts', '.', 'Children', 'play', 'in', 'the', 'park', ',', 'their', 'laughter', 'echoing', 'through', 'the', 'open', 'space', '.', 'A', 'gentle', 'breeze', 'rustles', 'the', 'leaves', ',', 'bringing', 'relief', 'from', 'the', 'summer', 'heat', '.', 'A', 'rainbow', 'appears', 'after', 'the', 'rain', ',', 'painting', 'the', 'sky', 'with', 'vibrant', 'colors', '.', 'The', 'waves', 'crash', 'against', 'the', 'shore', ',', 'creating', 'a', 'soothing', 'rhythm', '.', 'The', 'aroma', 'of', 'freshly', 'baked', 'bread', 'wafts', 'from', 'the', 'nearby', 'bakery', ',', 'tempting', 'passersby', '.', 'Friends', 'gather', 'around', 'a', 'bonfire', ',', 'sharing', 'stories', 'and', 'laughter', 'late', 'into', 'the', 'night', '.', 'The', 'city', 'comes', 'alive', 'with', 'lights', 'as', 'night', 'falls', ',', 'creating', 'a', 'magical', 'atmosphere', '.', 'Stars', 'twinkle', 'in', 'the', 'clear', 'night', 'sky', ',', 'inspiring', 'dreams', 'and', 'wonder', '.', 'The', 'scent', 'of', 'blooming', 'flowers', 'fills', 'the', 'garden', ',', 'attracting', 'bees', 'and', 'butterflies', '.', 'A', 'couple', 'walks', 'hand', 'in', 'hand', 'along', 'a', 'moonlit', 'path', ',', 'enjoying', 'each', 'other', "'s", 'company', '.', 'Life', 'is', 'a', 'beautiful', 'journey', ',', 'filled', 'with', 'moments', 'of', 'joy', ',', 'love', ',', 'and', 'adventure', '.', 'Every', 'day', 'brings', 'new', 'opportunities', 'and', 'experiences', 'to', 'cherish', '.', 'Embrace', 'the', 'beauty', 'of', 'the', 'world', 'and', 'find', 'happiness', 'in', 'the', 'simple', 'pleasures', 'that', 'surround', 'you', '.']

# %%
# nltk.download('stopwords')

# %%
stop_words=set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_tokens={}
i=0

for token in tokens:
    filtered_tokens[i]=[t for t in tokens[token] if t.lower() not in stop_words]
    i=i+1

filtered_tokens[0]
# Out:
# ['sun',
#  'sets',
#  'west',
#  ',',
#  'casting',
#  'warm',
#  'glow',
#  'across',
#  'horizon',
#  '.',
#  'Birds',
#  'chirp',
#  'happily',
#  'trees',
#  ',',
#  'creating',
#  'melodious',
#  'symphony',
#  '.',
#  'smell',
#  'freshly',
#  'brewed',
#  'coffee',
#  'fills',
#  'air',
#  ',',
#  'awakening',
#  'senses',
#  '.',
#  'People',
#  'walk',
#  'briskly',
#  'bustling',
#  'streets',
#  ',',
#  'immersed',
#  'thoughts',
#  '.',
#  'Children',
#  'play',
#  'park',
#  ',',
#  'laughter',
#  'echoing',
#  'open',
#  'space',
#  '.',
#  'gentle',
#  'breeze',
#  'rustles',
#  'leaves',
#  ',',
#  'bringing',
#  'relief',
#  'summer',
#  'heat',
#  '.',
#  'rainbow',
#  'appears',
#  'rain',
#  ',',
#  'painting',
#  'sky',
#  'vibrant',
#  'colors',
#  '.',
#  'waves',
#  'crash',
#  'shore',
#  ',',
#  'creating',
#  'soothing',
#  'rhythm',
#  '.',
#  'aroma',
#  'freshly',
#  'baked',
#  'bread',
#  'wafts',
#  'nearby',
#  'bakery',
#  ',',
#  'tempting',
#  'passersby',
#  '.',
#  'Friends',
#  'gather',
#  'around',
#  'bonfire',
#  ',',
#  'sharing',
#  'stories',
#  'laughter',
#  'late',
#  'night',
#  '.',
#  'city',
#  'comes',
#  'alive',
#  'lights',
#  'night',
#  'falls',
#  ',',
#  'creating',
#  'magical',
#  'atmosphere',
#  '.',
#  'Stars',
#  'twinkle',
#  'clear',
#  'night',
#  'sky',
#  ',',
#  'inspiring',
#  'dreams',
#  'wonder',
#  '.',
#  'scent',
#  'blooming',
#  'flowers',
#  'fills',
#  'garden',
#  ',',
#  'attracting',
#  'bees',
#  'butterflies',
#  '.',
#  'couple',
#  'walks',
#  'hand',
#  'hand',
#  'along',
#  'moonlit',
#  'path',
#  ',',
#  'enjoying',
#  "'s",
#  'company',
#  '.',
#  'Life',
#  'beautiful',
#  'journey',
#  ',',
#  'filled',
#  'moments',
#  'joy',
#  ',',
#  'love',
#  ',',
#  'adventure',
#  '.',
#  'Every',
#  'day',
#  'brings',
#  'new',
#  'opportunities',
#  'experiences',
#  'cherish',
#  '.',
#  'Embrace',
#  'beauty',
#  'world',
#  'find',
#  'happiness',
#  'simple',
#  'pleasures',
#  'surround',
#  '.']

# %%
stemmer=PorterStemmer()
stemmed_tokens={}
i=0

for filtered_token in filtered_tokens:
    stemmed_tokens[i]=[stemmer.stem(token) for token in filtered_tokens[filtered_token]]
    i=i+1

stemmed_tokens[0]
# Out:
# ['sun',
#  'set',
#  'west',
#  ',',
#  'cast',
#  'warm',
#  'glow',
#  'across',
#  'horizon',
#  '.',
#  'bird',
#  'chirp',
#  'happili',
#  'tree',
#  ',',
#  'creat',
#  'melodi',
#  'symphoni',
#  '.',
#  'smell',
#  'freshli',
#  'brew',
#  'coffe',
#  'fill',
#  'air',
#  ',',
#  'awaken',
#  'sens',
#  '.',
#  'peopl',
#  'walk',
#  'briskli',
#  'bustl',
#  'street',
#  ',',
#  'immers',
#  'thought',
#  '.',
#  'children',
#  'play',
#  'park',
#  ',',
#  'laughter',
#  'echo',
#  'open',
#  'space',
#  '.',
#  'gentl',
#  'breez',
#  'rustl',
#  'leav',
#  ',',
#  'bring',
#  'relief',
#  'summer',
#  'heat',
#  '.',
#  'rainbow',
#  'appear',
#  'rain',
#  ',',
#  'paint',
#  'sky',
#  'vibrant',
#  'color',
#  '.',
#  'wave',
#  'crash',
#  'shore',
#  ',',
#  'creat',
#  'sooth',
#  'rhythm',
#  '.',
#  'aroma',
#  'freshli',
#  'bake',
#  'bread',
#  'waft',
#  'nearbi',
#  'bakeri',
#  ',',
#  'tempt',
#  'passersbi',
#  '.',
#  'friend',
#  'gather',
#  'around',
#  'bonfir',
#  ',',
#  'share',
#  'stori',
#  'laughter',
#  'late',
#  'night',
#  '.',
#  'citi',
#  'come',
#  'aliv',
#  'light',
#  'night',
#  'fall',
#  ',',
#  'creat',
#  'magic',
#  'atmospher',
#  '.',
#  'star',
#  'twinkl',
#  'clear',
#  'night',
#  'sky',
#  ',',
#  'inspir',
#  'dream',
#  'wonder',
#  '.',
#  'scent',
#  'bloom',
#  'flower',
#  'fill',
#  'garden',
#  ',',
#  'attract',
#  'bee',
#  'butterfli',
#  '.',
#  'coupl',
#  'walk',
#  'hand',
#  'hand',
#  'along',
#  'moonlit',
#  'path',
#  ',',
#  'enjoy',
#  "'s",
#  'compani',
#  '.',
#  'life',
#  'beauti',
#  'journey',
#  ',',
#  'fill',
#  'moment',
#  'joy',
#  ',',
#  'love',
#  ',',
#  'adventur',
#  '.',
#  'everi',
#  'day',
#  'bring',
#  'new',
#  'opportun',
#  'experi',
#  'cherish',
#  '.',
#  'embrac',
#  'beauti',
#  'world',
#  'find',
#  'happi',
#  'simpl',
#  'pleasur',
#  'surround',
#  '.']

# %%
# nltk.download('wordnet')

# %%
lemmatizer=WordNetLemmatizer()
lemmatized_tokens={}
i=0

for stemmed_token in stemmed_tokens:
    lemmatized_tokens[i]=[lemmatizer.lemmatize(token) for token in stemmed_tokens[stemmed_token]]
    i=i+1

lemmatized_tokens[0]
# Out:
# ['sun',
#  'set',
#  'west',
#  ',',
#  'cast',
#  'warm',
#  'glow',
#  'across',
#  'horizon',
#  '.',
#  'bird',
#  'chirp',
#  'happili',
#  'tree',
#  ',',
#  'creat',
#  'melodi',
#  'symphoni',
#  '.',
#  'smell',
#  'freshli',
#  'brew',
#  'coffe',
#  'fill',
#  'air',
#  ',',
#  'awaken',
#  'sen',
#  '.',
#  'peopl',
#  'walk',
#  'briskli',
#  'bustl',
#  'street',
#  ',',
#  'immers',
#  'thought',
#  '.',
#  'child',
#  'play',
#  'park',
#  ',',
#  'laughter',
#  'echo',
#  'open',
#  'space',
#  '.',
#  'gentl',
#  'breez',
#  'rustl',
#  'leav',
#  ',',
#  'bring',
#  'relief',
#  'summer',
#  'heat',
#  '.',
#  'rainbow',
#  'appear',
#  'rain',
#  ',',
#  'paint',
#  'sky',
#  'vibrant',
#  'color',
#  '.',
#  'wave',
#  'crash',
#  'shore',
#  ',',
#  'creat',
#  'sooth',
#  'rhythm',
#  '.',
#  'aroma',
#  'freshli',
#  'bake',
#  'bread',
#  'waft',
#  'nearbi',
#  'bakeri',
#  ',',
#  'tempt',
#  'passersbi',
#  '.',
#  'friend',
#  'gather',
#  'around',
#  'bonfir',
#  ',',
#  'share',
#  'stori',
#  'laughter',
#  'late',
#  'night',
#  '.',
#  'citi',
#  'come',
#  'aliv',
#  'light',
#  'night',
#  'fall',
#  ',',
#  'creat',
#  'magic',
#  'atmospher',
#  '.',
#  'star',
#  'twinkl',
#  'clear',
#  'night',
#  'sky',
#  ',',
#  'inspir',
#  'dream',
#  'wonder',
#  '.',
#  'scent',
#  'bloom',
#  'flower',
#  'fill',
#  'garden',
#  ',',
#  'attract',
#  'bee',
#  'butterfli',
#  '.',
#  'coupl',
#  'walk',
#  'hand',
#  'hand',
#  'along',
#  'moonlit',
#  'path',
#  ',',
#  'enjoy',
#  "'s",
#  'compani',
#  '.',
#  'life',
#  'beauti',
#  'journey',
#  ',',
#  'fill',
#  'moment',
#  'joy',
#  ',',
#  'love',
#  ',',
#  'adventur',
#  '.',
#  'everi',
#  'day',
#  'bring',
#  'new',
#  'opportun',
#  'experi',
#  'cherish',
#  '.',
#  'embrac',
#  'beauti',
#  'world',
#  'find',
#  'happi',
#  'simpl',
#  'pleasur',
#  'surround',
#  '.']

# %%
# nltk.download('averaged_perceptron_tagger')

# %%
pos_tags={}
i=0

for filtered_token in filtered_tokens:
    pos_tags[i]=pos_tag(filtered_tokens[filtered_token])
    i=i+1

pos_tags[0]
# Out:
# [('sun', 'JJ'),
#  ('sets', 'NNS'),
#  ('west', 'JJS'),
#  (',', ','),
#  ('casting', 'VBG'),
#  ('warm', 'JJ'),
#  ('glow', 'NN'),
#  ('across', 'IN'),
#  ('horizon', 'NN'),
#  ('.', '.'),
#  ('Birds', 'NNS'),
#  ('chirp', 'VBP'),
#  ('happily', 'RB'),
#  ('trees', 'NNS'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('melodious', 'JJ'),
#  ('symphony', 'NN'),
#  ('.', '.'),
#  ('smell', 'VB'),
#  ('freshly', 'RB'),
#  ('brewed', 'VBN'),
#  ('coffee', 'NN'),
#  ('fills', 'NNS'),
#  ('air', 'NN'),
#  (',', ','),
#  ('awakening', 'VBG'),
#  ('senses', 'NNS'),
#  ('.', '.'),
#  ('People', 'NNS'),
#  ('walk', 'VBP'),
#  ('briskly', 'RB'),
#  ('bustling', 'VBG'),
#  ('streets', 'NNS'),
#  (',', ','),
#  ('immersed', 'VBN'),
#  ('thoughts', 'NNS'),
#  ('.', '.'),
#  ('Children', 'NNP'),
#  ('play', 'NN'),
#  ('park', 'NN'),
#  (',', ','),
#  ('laughter', 'NN'),
#  ('echoing', 'VBG'),
#  ('open', 'JJ'),
#  ('space', 'NN'),
#  ('.', '.'),
#  ('gentle', 'JJ'),
#  ('breeze', 'NN'),
#  ('rustles', 'VBZ'),
#  ('leaves', 'NNS'),
#  (',', ','),
#  ('bringing', 'VBG'),
#  ('relief', 'NN'),
#  ('summer', 'NN'),
#  ('heat', 'NN'),
#  ('.', '.'),
#  ('rainbow', 'NN'),
#  ('appears', 'VBZ'),
#  ('rain', 'NN'),
#  (',', ','),
#  ('painting', 'VBG'),
#  ('sky', 'NN'),
#  ('vibrant', 'NN'),
#  ('colors', 'NNS'),
#  ('.', '.'),
#  ('waves', 'NNS'),
#  ('crash', 'NN'),
#  ('shore', 'NN'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('soothing', 'VBG'),
#  ('rhythm', 'NN'),
#  ('.', '.'),
#  ('aroma', 'NN'),
#  ('freshly', 'RB'),
#  ('baked', 'VBN'),
#  ('bread', 'JJ'),
#  ('wafts', 'NNS'),
#  ('nearby', 'RB'),
#  ('bakery', 'RB'),
#  (',', ','),
#  ('tempting', 'VBG'),
#  ('passersby', 'NN'),
#  ('.', '.'),
#  ('Friends', 'NNPS'),
#  ('gather', 'VBP'),
#  ('around', 'IN'),
#  ('bonfire', 'NN'),
#  (',', ','),
#  ('sharing', 'VBG'),
#  ('stories', 'NNS'),
#  ('laughter', 'RBR'),
#  ('late', 'RB'),
#  ('night', 'NN'),
#  ('.', '.'),
#  ('city', 'NN'),
#  ('comes', 'VBZ'),
#  ('alive', 'JJ'),
#  ('lights', 'NNS'),
#  ('night', 'NN'),
#  ('falls', 'VBZ'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('magical', 'JJ'),
#  ('atmosphere', 'NN'),
#  ('.', '.'),
#  ('Stars', 'NNP'),
#  ('twinkle', 'VBD'),
#  ('clear', 'JJ'),
#  ('night', 'NN'),
#  ('sky', 'NN'),
#  (',', ','),
#  ('inspiring', 'VBG'),
#  ('dreams', 'NNS'),
#  ('wonder', 'VBP'),
#  ('.', '.'),
#  ('scent', 'NN'),
#  ('blooming', 'VBG'),
#  ('flowers', 'NNS'),
#  ('fills', 'NNS'),
#  ('garden', 'NN'),
#  (',', ','),
#  ('attracting', 'VBG'),
#  ('bees', 'NNS'),
#  ('butterflies', 'NNS'),
#  ('.', '.'),
#  ('couple', 'NN'),
#  ('walks', 'NNS'),
#  ('hand', 'NN'),
#  ('hand', 'NN'),
#  ('along', 'IN'),
#  ('moonlit', 'JJ'),
#  ('path', 'NN'),
#  (',', ','),
#  ('enjoying', 'VBG'),
#  ("'s", 'POS'),
#  ('company', 'NN'),
#  ('.', '.'),
#  ('Life', 'NNP'),
#  ('beautiful', 'JJ'),
#  ('journey', 'NN'),
#  (',', ','),
#  ('filled', 'VBD'),
#  ('moments', 'NNS'),
#  ('joy', 'NN'),
#  (',', ','),
#  ('love', 'NN'),
#  (',', ','),
#  ('adventure', 'NN'),
#  ('.', '.'),
#  ('Every', 'DT'),
#  ('day', 'NN'),
#  ('brings', 'VBZ'),
#  ('new', 'JJ'),
#  ('opportunities', 'NNS'),
#  ('experiences', 'VBZ'),
#  ('cherish', 'JJ'),
#  ('.', '.'),
#  ('Embrace', 'NNP'),
#  ('beauty', 'NN'),
#  ('world', 'NN'),
#  ('find', 'VBP'),
#  ('happiness', 'JJ'),
#  ('simple', 'JJ'),
#  ('pleasures', 'NNS'),
#  ('surround', 'VBP'),
#  ('.', '.')]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer=TfidfVectorizer()
tfidf_matrix=vectorizer.fit_transform(docs)

feature_names=vectorizer.get_feature_names_out()

for i in range(len(docs)):
    print("Document : ",docs[i])
    for j, word in enumerate(feature_names):
        tfidf_value=tfidf_matrix[i,j]
        print("Word : ",word,"TF-IDF : ",tfidf_value)
# Out:
# Document :  The sun sets in the west, casting a warm glow across the horizon. Birds chirp happily in the trees, creating a melodious symphony. The smell of freshly brewed coffee fills the air, awakening the senses. People walk briskly on the bustling streets, immersed in their own thoughts. Children play in the park, their laughter echoing through the open space.
#
# A gentle breeze rustles the leaves, bringing relief from the summer heat. A rainbow appears after the rain, painting the sky with vibrant colors. The waves crash against the shore, creating a soothing rhythm. The aroma of freshly baked bread wafts from the nearby bakery, tempting passersby. Friends gather around a bonfire, sharing stories and laughter late into the night.
#
# The city comes alive with lights as night falls, creating a magical atmosphere. Stars twinkle in the clear night sky, inspiring dreams and wonder. The scent of blooming flowers fills the garden, attracting bees and butterflies. A couple walks hand in hand along a moonlit path, enjoying each other's company.
#
# Life is a beautiful journey, filled with moments of joy, love, and adventure. Every day brings new opportunities and experiences to cherish. Embrace the beauty of the world and find happiness in the simple pleasures that surround you.
#
#
# Word :  across TF-IDF :  0.03873444618261888
# Word :  activity TF-IDF :  0.0
# Word :  adding TF-IDF :  0.0
# Word :  adventure TF-IDF :  0.030080752859180115
# Word :  after TF-IDF :  0.05093114189264133
# Word :  against TF-IDF :  0.030080752859180115
# Word :  air TF-IDF :  0.030080752859180115
# Word :  alive TF-IDF :  0.05093114189264133
# Word :  along TF-IDF :  0.03873444618261888
# Word :  ambiance TF-IDF :  0.0
# Word :  among TF-IDF :  0.0
# Word :  an TF-IDF :  0.0
# Word :  and TF-IDF :  0.18048451715508068
# Word :  appears TF-IDF :  0.05093114189264133
# Word :  apple TF-IDF :  0.0
# Word :  are TF-IDF :  0.0
# Word :  aroma TF-IDF :  0.030080752859180115
# Word :  around TF-IDF :  0.03873444618261888
# Word :  array TF-IDF :  0.0
# Word :  art TF-IDF :  0.0
# Word :  as TF-IDF :  0.030080752859180115
# Word :  atmosphere TF-IDF :  0.03873444618261888
# Word :  attracting TF-IDF :  0.05093114189264133
# Word :  audiences TF-IDF :  0.0
# Word :  awakening TF-IDF :  0.05093114189264133
# Word :  awe TF-IDF :  0.0
# Word :  babbling TF-IDF :  0.0
# Word :  baked TF-IDF :  0.03873444618261888
# Word :  bakery TF-IDF :  0.05093114189264133
# Word :  bargaining TF-IDF :  0.0
# Word :  baristas TF-IDF :  0.0
# Word :  bask TF-IDF :  0.0
# Word :  be TF-IDF :  0.0
# Word :  beach TF-IDF :  0.0
# Word :  beachgoers TF-IDF :  0.0
# Word :  beautiful TF-IDF :  0.03873444618261888
# Word :  beauty TF-IDF :  0.030080752859180115
# Word :  bees TF-IDF :  0.05093114189264133
# Word :  birds TF-IDF :  0.03873444618261888
# Word :  blooming TF-IDF :  0.05093114189264133
# Word :  blue TF-IDF :  0.0
# Word :  bonfire TF-IDF :  0.05093114189264133
# Word :  bread TF-IDF :  0.05093114189264133
# Word :  breathtaking TF-IDF :  0.0
# Word :  breeze TF-IDF :  0.03873444618261888
# Word :  brewed TF-IDF :  0.03873444618261888
# Word :  brightly TF-IDF :  0.0
# Word :  bringing TF-IDF :  0.05093114189264133
# Word :  brings TF-IDF :  0.05093114189264133
# Word :  briskly TF-IDF :  0.05093114189264133
# Word :  brook TF-IDF :  0.0
# Word :  buds TF-IDF :  0.0
# Word :  build TF-IDF :  0.0
# Word :  bustling TF-IDF :  0.030080752859180115
# Word :  butterflies TF-IDF :  0.05093114189264133
# Word :  by TF-IDF :  0.0
# Word :  cafe TF-IDF :  0.0
# Word :  candlelight TF-IDF :  0.0
# Word :  canopy TF-IDF :  0.0
# Word :  capped TF-IDF :  0.0
# Word :  captivate TF-IDF :  0.0
# Word :  casting TF-IDF :  0.03873444618261888
# Word :  casts TF-IDF :  0.0
# Word :  celestial TF-IDF :  0.0
# Word :  charm TF-IDF :  0.0
# Word :  chatter TF-IDF :  0.0
# Word :  cherish TF-IDF :  0.05093114189264133
# Word :  cherished TF-IDF :  0.0
# Word :  cherishing TF-IDF :  0.0
# Word :  children TF-IDF :  0.03873444618261888
# Word :  chirp TF-IDF :  0.03873444618261888
# Word :  cities TF-IDF :  0.0
# Word :  city TF-IDF :  0.03873444618261888
# Word :  clear TF-IDF :  0.03873444618261888
# Word :  coat TF-IDF :  0.0
# Word :  coffee TF-IDF :  0.03873444618261888
# Word :  colorful TF-IDF :  0.0
# Word :  colors TF-IDF :  0.05093114189264133
# Word :  comes TF-IDF :  0.05093114189264133
# Word :  company TF-IDF :  0.05093114189264133
# Word :  conversations TF-IDF :  0.0
# Word :  corner TF-IDF :  0.0
# Word :  cottage TF-IDF :  0.0
# Word :  couple TF-IDF :  0.05093114189264133
# Word :  cozy TF-IDF :  0.0
# Word :  crackling TF-IDF :  0.0
# Word :  craft TF-IDF :  0.0
# Word :  crash TF-IDF :  0.03873444618261888
# Word :  creating TF-IDF :  0.09024225857754034
# Word :  creatures TF-IDF :  0.0
# Word :  crickets TF-IDF :  0.0
# Word :  cuisines TF-IDF :  0.0
# Word :  culinary TF-IDF :  0.0
# Word :  dance TF-IDF :  0.0
# Word :  darkness TF-IDF :  0.0
# Word :  day TF-IDF :  0.03873444618261888
# Word :  deer TF-IDF :  0.0
# Word :  delicious TF-IDF :  0.0
# Word :  discovery TF-IDF :  0.0
# Word :  display TF-IDF :  0.0
# Word :  distance TF-IDF :  0.0
# Word :  diverse TF-IDF :  0.0
# Word :  diversity TF-IDF :  0.0
# Word :  dreams TF-IDF :  0.05093114189264133
# Word :  each TF-IDF :  0.030080752859180115
# Word :  earth TF-IDF :  0.0
# Word :  echoes TF-IDF :  0.0
# Word :  echoing TF-IDF :  0.05093114189264133
# Word :  embrace TF-IDF :  0.030080752859180115
# Word :  encounters TF-IDF :  0.0
# Word :  energy TF-IDF :  0.0
# Word :  enjoying TF-IDF :  0.03873444618261888
# Word :  enticing TF-IDF :  0.0
# Word :  every TF-IDF :  0.030080752859180115
# Word :  everyone TF-IDF :  0.0
# Word :  experience TF-IDF :  0.0
# Word :  experiences TF-IDF :  0.03873444618261888
# Word :  falls TF-IDF :  0.03873444618261888
# Word :  family TF-IDF :  0.0
# Word :  feast TF-IDF :  0.0
# Word :  field TF-IDF :  0.0
# Word :  fill TF-IDF :  0.0
# Word :  filled TF-IDF :  0.030080752859180115
# Word :  filling TF-IDF :  0.0
# Word :  fills TF-IDF :  0.06016150571836023
# Word :  find TF-IDF :  0.05093114189264133
# Word :  fireflies TF-IDF :  0.0
# Word :  fireplace TF-IDF :  0.0
# Word :  flight TF-IDF :  0.0
# Word :  flowers TF-IDF :  0.05093114189264133
# Word :  for TF-IDF :  0.0
# Word :  forest TF-IDF :  0.0
# Word :  freshly TF-IDF :  0.06016150571836023
# Word :  friendly TF-IDF :  0.0
# Word :  friends TF-IDF :  0.03873444618261888
# Word :  from TF-IDF :  0.06016150571836023
# Word :  fruits TF-IDF :  0.0
# Word :  garden TF-IDF :  0.05093114189264133
# Word :  gather TF-IDF :  0.03873444618261888
# Word :  gentle TF-IDF :  0.030080752859180115
# Word :  glow TF-IDF :  0.030080752859180115
# Word :  graceful TF-IDF :  0.0
# Word :  gracefully TF-IDF :  0.0
# Word :  green TF-IDF :  0.0
# Word :  guiding TF-IDF :  0.0
# Word :  hand TF-IDF :  0.10186228378528266
# Word :  happily TF-IDF :  0.05093114189264133
# Word :  happiness TF-IDF :  0.05093114189264133
# Word :  heat TF-IDF :  0.05093114189264133
# Word :  holds TF-IDF :  0.0
# Word :  hoot TF-IDF :  0.0
# Word :  horizon TF-IDF :  0.05093114189264133
# Word :  hub TF-IDF :  0.0
# Word :  hues TF-IDF :  0.0
# Word :  hurry TF-IDF :  0.0
# Word :  illuminate TF-IDF :  0.0
# Word :  illuminates TF-IDF :  0.0
# Word :  illuminating TF-IDF :  0.0
# Word :  immersed TF-IDF :  0.03873444618261888
# Word :  in TF-IDF :  0.2105652700142608
# Word :  inspiring TF-IDF :  0.05093114189264133
# Word :  into TF-IDF :  0.03873444618261888
# Word :  intricate TF-IDF :  0.0
# Word :  is TF-IDF :  0.030080752859180115
# Word :  it TF-IDF :  0.0
# Word :  its TF-IDF :  0.0
# Word :  journey TF-IDF :  0.030080752859180115
# Word :  joy TF-IDF :  0.030080752859180115
# Word :  kitchen TF-IDF :  0.0
# Word :  lakeside TF-IDF :  0.0
# Word :  landscape TF-IDF :  0.0
# Word :  landscapes TF-IDF :  0.0
# Word :  late TF-IDF :  0.05093114189264133
# Word :  latte TF-IDF :  0.0
# Word :  laughter TF-IDF :  0.06016150571836023
# Word :  leaps TF-IDF :  0.0
# Word :  leaves TF-IDF :  0.03873444618261888
# Word :  let TF-IDF :  0.0
# Word :  life TF-IDF :  0.030080752859180115
# Word :  light TF-IDF :  0.0
# Word :  lights TF-IDF :  0.03873444618261888
# Word :  little TF-IDF :  0.0
# Word :  lively TF-IDF :  0.0
# Word :  love TF-IDF :  0.03873444618261888
# Word :  lush TF-IDF :  0.0
# Word :  magic TF-IDF :  0.0
# Word :  magical TF-IDF :  0.05093114189264133
# Word :  majestic TF-IDF :  0.0
# Word :  market TF-IDF :  0.0
# Word :  meadow TF-IDF :  0.0
# Word :  melodic TF-IDF :  0.0
# Word :  melodious TF-IDF :  0.05093114189264133
# Word :  melody TF-IDF :  0.0
# Word :  memories TF-IDF :  0.0
# Word :  mesmerizing TF-IDF :  0.0
# Word :  moments TF-IDF :  0.030080752859180115
# Word :  moon TF-IDF :  0.0
# Word :  moonlit TF-IDF :  0.05093114189264133
# Word :  mountains TF-IDF :  0.0
# Word :  mystique TF-IDF :  0.0
# Word :  natural TF-IDF :  0.0
# Word :  nature TF-IDF :  0.0
# Word :  nearby TF-IDF :  0.05093114189264133
# Word :  neon TF-IDF :  0.0
# Word :  nestled TF-IDF :  0.0
# Word :  new TF-IDF :  0.05093114189264133
# Word :  night TF-IDF :  0.09024225857754034
# Word :  nocturnal TF-IDF :  0.0
# Word :  of TF-IDF :  0.15040376429590058
# Word :  offers TF-IDF :  0.0
# Word :  on TF-IDF :  0.03873444618261888
# Word :  open TF-IDF :  0.05093114189264133
# Word :  opportunities TF-IDF :  0.05093114189264133
# Word :  orange TF-IDF :  0.0
# Word :  other TF-IDF :  0.05093114189264133
# Word :  over TF-IDF :  0.0
# Word :  overhead TF-IDF :  0.0
# Word :  owls TF-IDF :  0.0
# Word :  own TF-IDF :  0.030080752859180115
# Word :  painting TF-IDF :  0.030080752859180115
# Word :  park TF-IDF :  0.05093114189264133
# Word :  passersby TF-IDF :  0.03873444618261888
# Word :  path TF-IDF :  0.05093114189264133
# Word :  patrons TF-IDF :  0.0
# Word :  peaceful TF-IDF :  0.0
# Word :  peaks TF-IDF :  0.0
# Word :  people TF-IDF :  0.03873444618261888
# Word :  performers TF-IDF :  0.0
# Word :  permeates TF-IDF :  0.0
# Word :  pie TF-IDF :  0.0
# Word :  pine TF-IDF :  0.0
# Word :  pink TF-IDF :  0.0
# Word :  play TF-IDF :  0.05093114189264133
# Word :  pleasures TF-IDF :  0.05093114189264133
# Word :  quaint TF-IDF :  0.0
# Word :  rain TF-IDF :  0.05093114189264133
# Word :  rainbow TF-IDF :  0.05093114189264133
# Word :  rays TF-IDF :  0.0
# Word :  refreshing TF-IDF :  0.0
# Word :  relaxation TF-IDF :  0.0
# Word :  relief TF-IDF :  0.05093114189264133
# Word :  remarkable TF-IDF :  0.0
# Word :  rhythm TF-IDF :  0.03873444618261888
# Word :  rise TF-IDF :  0.0
# Word :  romantic TF-IDF :  0.0
# Word :  room TF-IDF :  0.0
# Word :  rustles TF-IDF :  0.03873444618261888
# Word :  sandcastles TF-IDF :  0.0
# Word :  sandy TF-IDF :  0.0
# Word :  savor TF-IDF :  0.0
# Word :  scent TF-IDF :  0.030080752859180115
# Word :  seagulls TF-IDF :  0.0
# Word :  sense TF-IDF :  0.0
# Word :  senses TF-IDF :  0.03873444618261888
# Word :  serenade TF-IDF :  0.0
# Word :  serene TF-IDF :  0.0
# Word :  sets TF-IDF :  0.03873444618261888
# Word :  settles TF-IDF :  0.0
# Word :  sharing TF-IDF :  0.03873444618261888
# Word :  shimmering TF-IDF :  0.0
# Word :  shines TF-IDF :  0.0
# Word :  shore TF-IDF :  0.03873444618261888
# Word :  simple TF-IDF :  0.05093114189264133
# Word :  sip TF-IDF :  0.0
# Word :  skillfully TF-IDF :  0.0
# Word :  skin TF-IDF :  0.0
# Word :  sky TF-IDF :  0.06016150571836023
# Word :  skyline TF-IDF :  0.0
# Word :  smell TF-IDF :  0.05093114189264133
# Word :  snow TF-IDF :  0.0
# Word :  soar TF-IDF :  0.0
# Word :  soft TF-IDF :  0.0
# Word :  songs TF-IDF :  0.0
# Word :  soothing TF-IDF :  0.03873444618261888
# Word :  sound TF-IDF :  0.0
# Word :  sounds TF-IDF :  0.0
# Word :  space TF-IDF :  0.030080752859180115
# Word :  spices TF-IDF :  0.0
# Word :  stars TF-IDF :  0.030080752859180115
# Word :  stories TF-IDF :  0.03873444618261888
# Word :  street TF-IDF :  0.0
# Word :  streets TF-IDF :  0.03873444618261888
# Word :  summer TF-IDF :  0.05093114189264133
# Word :  sun TF-IDF :  0.030080752859180115
# Word :  sunlight TF-IDF :  0.0
# Word :  surround TF-IDF :  0.03873444618261888
# Word :  surrounds TF-IDF :  0.0
# Word :  sways TF-IDF :  0.0
# Word :  symphony TF-IDF :  0.03873444618261888
# Word :  table TF-IDF :  0.0
# Word :  talents TF-IDF :  0.0
# Word :  tall TF-IDF :  0.0
# Word :  tapestry TF-IDF :  0.0
# Word :  taste TF-IDF :  0.0
# Word :  tempting TF-IDF :  0.030080752859180115
# Word :  that TF-IDF :  0.030080752859180115
# Word :  the TF-IDF :  0.7820995743386829
# Word :  their TF-IDF :  0.06016150571836023
# Word :  thoughts TF-IDF :  0.05093114189264133
# Word :  thread TF-IDF :  0.0
# Word :  through TF-IDF :  0.030080752859180115
# Word :  throughout TF-IDF :  0.0
# Word :  to TF-IDF :  0.030080752859180115
# Word :  touch TF-IDF :  0.0
# Word :  tranquility TF-IDF :  0.0
# Word :  trees TF-IDF :  0.030080752859180115
# Word :  turning TF-IDF :  0.0
# Word :  twinkle TF-IDF :  0.030080752859180115
# Word :  unfold TF-IDF :  0.0
# Word :  unique TF-IDF :  0.0
# Word :  upon TF-IDF :  0.0
# Word :  urban TF-IDF :  0.0
# Word :  valley TF-IDF :  0.0
# Word :  vegetables TF-IDF :  0.0
# Word :  velvety TF-IDF :  0.0
# Word :  vendors TF-IDF :  0.0
# Word :  vibrant TF-IDF :  0.030080752859180115
# Word :  wafts TF-IDF :  0.03873444618261888
# Word :  walk TF-IDF :  0.05093114189264133
# Word :  walks TF-IDF :  0.05093114189264133
# Word :  warm TF-IDF :  0.03873444618261888
# Word :  warms TF-IDF :  0.0
# Word :  warmth TF-IDF :  0.0
# Word :  watch TF-IDF :  0.0
# Word :  waves TF-IDF :  0.03873444618261888
# Word :  way TF-IDF :  0.0
# Word :  weaves TF-IDF :  0.0
# Word :  west TF-IDF :  0.05093114189264133
# Word :  while TF-IDF :  0.0
# Word :  wildflowers TF-IDF :  0.0
# Word :  wind TF-IDF :  0.0
# Word :  with TF-IDF :  0.09024225857754034
# Word :  wonder TF-IDF :  0.03873444618261888
# Word :  wonders TF-IDF :  0.0
# Word :  work TF-IDF :  0.0
# Word :  world TF-IDF :  0.030080752859180115
# Word :  worlds TF-IDF :  0.0
# Word :  worth TF-IDF :  0.0
# Word :  woven TF-IDF :  0.0
# Word :  you TF-IDF :  0.030080752859180115
# Document :  The gentle breeze rustles through the leaves, creating a soothing melody. Birds chirp in the distance, their melodic songs filling the air. A field of colorful wildflowers sways gracefully in the wind, painting the landscape with vibrant hues. The sun shines brightly, casting its warm rays upon the earth.
#
# In a quaint little cafe, the aroma of freshly brewed coffee fills the air, enticing passersby. Baristas skillfully craft intricate latte art, turning coffee into a work of art. The sound of friendly chatter and laughter echoes throughout the cozy space. Patrons savor each sip, enjoying moments of relaxation.
#
# On a sandy beach, waves crash against the shore, creating a symphony of sounds. Children build sandcastles, their laughter filling the air with joy. Seagulls soar overhead, their graceful flight against the blue sky mesmerizing to watch. Beachgoers bask in the sun, enjoying the warmth on their skin.
#
# In a bustling market, vendors display their colorful array of fruits and vegetables. The scent of spices wafts through the air, tempting taste buds. Bargaining and lively conversations fill the atmosphere, creating a lively and vibrant ambiance. The market is a hub of activity and a feast for the senses.
#
# As night falls, stars twinkle in the velvety sky, illuminating the world with their celestial glow. The moon casts a gentle light, creating a romantic atmosphere. Fireflies dance among the trees, their soft glow adding a touch of magic to the night. Night owls hoot in the distance, while crickets serenade the darkness.
#
# Life is a beautiful journey, filled with moments of wonder and awe. From the tranquility of nature to the energy of bustling cities, every experience holds its own charm. Embrace the diversity and beauty that surrounds you, and let each day be an adventure worth cherishing.
#
#
#
# Word :  across TF-IDF :  0.0
# Word :  activity TF-IDF :  0.03886227480284923
# Word :  adding TF-IDF :  0.029555761680312927
# Word :  adventure TF-IDF :  0.022952685536762947
# Word :  after TF-IDF :  0.0
# Word :  against TF-IDF :  0.045905371073525894
# Word :  air TF-IDF :  0.09181074214705179
# Word :  alive TF-IDF :  0.0
# Word :  along TF-IDF :  0.0
# Word :  ambiance TF-IDF :  0.029555761680312927
# Word :  among TF-IDF :  0.03886227480284923
# Word :  an TF-IDF :  0.03886227480284923
# Word :  and TF-IDF :  0.18362148429410358
# Word :  appears TF-IDF :  0.0
# Word :  apple TF-IDF :  0.0
# Word :  are TF-IDF :  0.0
# Word :  aroma TF-IDF :  0.022952685536762947
# Word :  around TF-IDF :  0.0
# Word :  array TF-IDF :  0.03886227480284923
# Word :  art TF-IDF :  0.07772454960569845
# Word :  as TF-IDF :  0.022952685536762947
# Word :  atmosphere TF-IDF :  0.059111523360625855
# Word :  attracting TF-IDF :  0.0
# Word :  audiences TF-IDF :  0.0
# Word :  awakening TF-IDF :  0.0
# Word :  awe TF-IDF :  0.03886227480284923
# Word :  babbling TF-IDF :  0.0
# Word :  baked TF-IDF :  0.0
# Word :  bakery TF-IDF :  0.0
# Word :  bargaining TF-IDF :  0.03886227480284923
# Word :  baristas TF-IDF :  0.03886227480284923
# Word :  bask TF-IDF :  0.03886227480284923
# Word :  be TF-IDF :  0.03886227480284923
# Word :  beach TF-IDF :  0.03886227480284923
# Word :  beachgoers TF-IDF :  0.03886227480284923
# Word :  beautiful TF-IDF :  0.029555761680312927
# Word :  beauty TF-IDF :  0.022952685536762947
# Word :  bees TF-IDF :  0.0
# Word :  birds TF-IDF :  0.029555761680312927
# Word :  blooming TF-IDF :  0.0
# Word :  blue TF-IDF :  0.029555761680312927
# Word :  bonfire TF-IDF :  0.0
# Word :  bread TF-IDF :  0.0
# Word :  breathtaking TF-IDF :  0.0
# Word :  breeze TF-IDF :  0.029555761680312927
# Word :  brewed TF-IDF :  0.029555761680312927
# Word :  brightly TF-IDF :  0.029555761680312927
# Word :  bringing TF-IDF :  0.0
# Word :  brings TF-IDF :  0.0
# Word :  briskly TF-IDF :  0.0
# Word :  brook TF-IDF :  0.0
# Word :  buds TF-IDF :  0.029555761680312927
# Word :  build TF-IDF :  0.03886227480284923
# Word :  bustling TF-IDF :  0.045905371073525894
# Word :  butterflies TF-IDF :  0.0
# Word :  by TF-IDF :  0.0
# Word :  cafe TF-IDF :  0.03886227480284923
# Word :  candlelight TF-IDF :  0.0
# Word :  canopy TF-IDF :  0.0
# Word :  capped TF-IDF :  0.0
# Word :  captivate TF-IDF :  0.0
# Word :  casting TF-IDF :  0.029555761680312927
# Word :  casts TF-IDF :  0.029555761680312927
# Word :  celestial TF-IDF :  0.03886227480284923
# Word :  charm TF-IDF :  0.03886227480284923
# Word :  chatter TF-IDF :  0.03886227480284923
# Word :  cherish TF-IDF :  0.0
# Word :  cherished TF-IDF :  0.0
# Word :  cherishing TF-IDF :  0.03886227480284923
# Word :  children TF-IDF :  0.029555761680312927
# Word :  chirp TF-IDF :  0.029555761680312927
# Word :  cities TF-IDF :  0.03886227480284923
# Word :  city TF-IDF :  0.0
# Word :  clear TF-IDF :  0.0
# Word :  coat TF-IDF :  0.0
# Word :  coffee TF-IDF :  0.059111523360625855
# Word :  colorful TF-IDF :  0.07772454960569845
# Word :  colors TF-IDF :  0.0
# Word :  comes TF-IDF :  0.0
# Word :  company TF-IDF :  0.0
# Word :  conversations TF-IDF :  0.03886227480284923
# Word :  corner TF-IDF :  0.0
# Word :  cottage TF-IDF :  0.0
# Word :  couple TF-IDF :  0.0
# Word :  cozy TF-IDF :  0.029555761680312927
# Word :  crackling TF-IDF :  0.0
# Word :  craft TF-IDF :  0.03886227480284923
# Word :  crash TF-IDF :  0.029555761680312927
# Word :  creating TF-IDF :  0.09181074214705179
# Word :  creatures TF-IDF :  0.0
# Word :  crickets TF-IDF :  0.03886227480284923
# Word :  cuisines TF-IDF :  0.0
# Word :  culinary TF-IDF :  0.0
# Word :  dance TF-IDF :  0.03886227480284923
# Word :  darkness TF-IDF :  0.03886227480284923
# Word :  day TF-IDF :  0.029555761680312927
# Word :  deer TF-IDF :  0.0
# Word :  delicious TF-IDF :  0.0
# Word :  discovery TF-IDF :  0.0
# Word :  display TF-IDF :  0.029555761680312927
# Word :  distance TF-IDF :  0.059111523360625855
# Word :  diverse TF-IDF :  0.0
# Word :  diversity TF-IDF :  0.03886227480284923
# Word :  dreams TF-IDF :  0.0
# Word :  each TF-IDF :  0.045905371073525894
# Word :  earth TF-IDF :  0.03886227480284923
# Word :  echoes TF-IDF :  0.03886227480284923
# Word :  echoing TF-IDF :  0.0
# Word :  embrace TF-IDF :  0.022952685536762947
# Word :  encounters TF-IDF :  0.0
# Word :  energy TF-IDF :  0.03886227480284923
# Word :  enjoying TF-IDF :  0.059111523360625855
# Word :  enticing TF-IDF :  0.029555761680312927
# Word :  every TF-IDF :  0.022952685536762947
# Word :  everyone TF-IDF :  0.0
# Word :  experience TF-IDF :  0.03886227480284923
# Word :  experiences TF-IDF :  0.0
# Word :  falls TF-IDF :  0.029555761680312927
# Word :  family TF-IDF :  0.0
# Word :  feast TF-IDF :  0.03886227480284923
# Word :  field TF-IDF :  0.03886227480284923
# Word :  fill TF-IDF :  0.03886227480284923
# Word :  filled TF-IDF :  0.022952685536762947
# Word :  filling TF-IDF :  0.07772454960569845
# Word :  fills TF-IDF :  0.022952685536762947
# Word :  find TF-IDF :  0.0
# Word :  fireflies TF-IDF :  0.03886227480284923
# Word :  fireplace TF-IDF :  0.0
# Word :  flight TF-IDF :  0.03886227480284923
# Word :  flowers TF-IDF :  0.0
# Word :  for TF-IDF :  0.029555761680312927
# Word :  forest TF-IDF :  0.0
# Word :  freshly TF-IDF :  0.022952685536762947
# Word :  friendly TF-IDF :  0.03886227480284923
# Word :  friends TF-IDF :  0.0
# Word :  from TF-IDF :  0.022952685536762947
# Word :  fruits TF-IDF :  0.03886227480284923
# Word :  garden TF-IDF :  0.0
# Word :  gather TF-IDF :  0.0
# Word :  gentle TF-IDF :  0.045905371073525894
# Word :  glow TF-IDF :  0.045905371073525894
# Word :  graceful TF-IDF :  0.03886227480284923
# Word :  gracefully TF-IDF :  0.029555761680312927
# Word :  green TF-IDF :  0.0
# Word :  guiding TF-IDF :  0.0
# Word :  hand TF-IDF :  0.0
# Word :  happily TF-IDF :  0.0
# Word :  happiness TF-IDF :  0.0
# Word :  heat TF-IDF :  0.0
# Word :  holds TF-IDF :  0.03886227480284923
# Word :  hoot TF-IDF :  0.029555761680312927
# Word :  horizon TF-IDF :  0.0
# Word :  hub TF-IDF :  0.03886227480284923
# Word :  hues TF-IDF :  0.029555761680312927
# Word :  hurry TF-IDF :  0.0
# Word :  illuminate TF-IDF :  0.0
# Word :  illuminates TF-IDF :  0.0
# Word :  illuminating TF-IDF :  0.03886227480284923
# Word :  immersed TF-IDF :  0.0
# Word :  in TF-IDF :  0.16066879875734064
# Word :  inspiring TF-IDF :  0.0
# Word :  into TF-IDF :  0.029555761680312927
# Word :  intricate TF-IDF :  0.03886227480284923
# Word :  is TF-IDF :  0.045905371073525894
# Word :  it TF-IDF :  0.0
# Word :  its TF-IDF :  0.059111523360625855
# Word :  journey TF-IDF :  0.022952685536762947
# Word :  joy TF-IDF :  0.022952685536762947
# Word :  kitchen TF-IDF :  0.0
# Word :  lakeside TF-IDF :  0.0
# Word :  landscape TF-IDF :  0.029555761680312927
# Word :  landscapes TF-IDF :  0.0
# Word :  late TF-IDF :  0.0
# Word :  latte TF-IDF :  0.03886227480284923
# Word :  laughter TF-IDF :  0.045905371073525894
# Word :  leaps TF-IDF :  0.0
# Word :  leaves TF-IDF :  0.029555761680312927
# Word :  let TF-IDF :  0.029555761680312927
# Word :  life TF-IDF :  0.022952685536762947
# Word :  light TF-IDF :  0.03886227480284923
# Word :  lights TF-IDF :  0.0
# Word :  little TF-IDF :  0.03886227480284923
# Word :  lively TF-IDF :  0.07772454960569845
# Word :  love TF-IDF :  0.0
# Word :  lush TF-IDF :  0.0
# Word :  magic TF-IDF :  0.03886227480284923
# Word :  magical TF-IDF :  0.0
# Word :  majestic TF-IDF :  0.0
# Word :  market TF-IDF :  0.07772454960569845
# Word :  meadow TF-IDF :  0.0
# Word :  melodic TF-IDF :  0.03886227480284923
# Word :  melodious TF-IDF :  0.0
# Word :  melody TF-IDF :  0.03886227480284923
# Word :  memories TF-IDF :  0.0
# Word :  mesmerizing TF-IDF :  0.03886227480284923
# Word :  moments TF-IDF :  0.045905371073525894
# Word :  moon TF-IDF :  0.029555761680312927
# Word :  moonlit TF-IDF :  0.0
# Word :  mountains TF-IDF :  0.0
# Word :  mystique TF-IDF :  0.0
# Word :  natural TF-IDF :  0.0
# Word :  nature TF-IDF :  0.03886227480284923
# Word :  nearby TF-IDF :  0.0
# Word :  neon TF-IDF :  0.0
# Word :  nestled TF-IDF :  0.0
# Word :  new TF-IDF :  0.0
# Word :  night TF-IDF :  0.06885805661028885
# Word :  nocturnal TF-IDF :  0.0
# Word :  of TF-IDF :  0.29838491197791833
# Word :  offers TF-IDF :  0.0
# Word :  on TF-IDF :  0.059111523360625855
# Word :  open TF-IDF :  0.0
# Word :  opportunities TF-IDF :  0.0
# Word :  orange TF-IDF :  0.0
# Word :  other TF-IDF :  0.0
# Word :  over TF-IDF :  0.0
# Word :  overhead TF-IDF :  0.03886227480284923
# Word :  owls TF-IDF :  0.029555761680312927
# Word :  own TF-IDF :  0.022952685536762947
# Word :  painting TF-IDF :  0.022952685536762947
# Word :  park TF-IDF :  0.0
# Word :  passersby TF-IDF :  0.029555761680312927
# Word :  path TF-IDF :  0.0
# Word :  patrons TF-IDF :  0.03886227480284923
# Word :  peaceful TF-IDF :  0.0
# Word :  peaks TF-IDF :  0.0
# Word :  people TF-IDF :  0.0
# Word :  performers TF-IDF :  0.0
# Word :  permeates TF-IDF :  0.0
# Word :  pie TF-IDF :  0.0
# Word :  pine TF-IDF :  0.0
# Word :  pink TF-IDF :  0.0
# Word :  play TF-IDF :  0.0
# Word :  pleasures TF-IDF :  0.0
# Word :  quaint TF-IDF :  0.03886227480284923
# Word :  rain TF-IDF :  0.0
# Word :  rainbow TF-IDF :  0.0
# Word :  rays TF-IDF :  0.03886227480284923
# Word :  refreshing TF-IDF :  0.0
# Word :  relaxation TF-IDF :  0.03886227480284923
# Word :  relief TF-IDF :  0.0
# Word :  remarkable TF-IDF :  0.0
# Word :  rhythm TF-IDF :  0.0
# Word :  rise TF-IDF :  0.0
# Word :  romantic TF-IDF :  0.03886227480284923
# Word :  room TF-IDF :  0.0
# Word :  rustles TF-IDF :  0.029555761680312927
# Word :  sandcastles TF-IDF :  0.03886227480284923
# Word :  sandy TF-IDF :  0.03886227480284923
# Word :  savor TF-IDF :  0.03886227480284923
# Word :  scent TF-IDF :  0.022952685536762947
# Word :  seagulls TF-IDF :  0.03886227480284923
# Word :  sense TF-IDF :  0.0
# Word :  senses TF-IDF :  0.029555761680312927
# Word :  serenade TF-IDF :  0.03886227480284923
# Word :  serene TF-IDF :  0.0
# Word :  sets TF-IDF :  0.0
# Word :  settles TF-IDF :  0.0
# Word :  sharing TF-IDF :  0.0
# Word :  shimmering TF-IDF :  0.0
# Word :  shines TF-IDF :  0.03886227480284923
# Word :  shore TF-IDF :  0.029555761680312927
# Word :  simple TF-IDF :  0.0
# Word :  sip TF-IDF :  0.03886227480284923
# Word :  skillfully TF-IDF :  0.03886227480284923
# Word :  skin TF-IDF :  0.03886227480284923
# Word :  sky TF-IDF :  0.045905371073525894
# Word :  skyline TF-IDF :  0.0
# Word :  smell TF-IDF :  0.0
# Word :  snow TF-IDF :  0.0
# Word :  soar TF-IDF :  0.03886227480284923
# Word :  soft TF-IDF :  0.029555761680312927
# Word :  songs TF-IDF :  0.03886227480284923
# Word :  soothing TF-IDF :  0.029555761680312927
# Word :  sound TF-IDF :  0.029555761680312927
# Word :  sounds TF-IDF :  0.03886227480284923
# Word :  space TF-IDF :  0.022952685536762947
# Word :  spices TF-IDF :  0.03886227480284923
# Word :  stars TF-IDF :  0.022952685536762947
# Word :  stories TF-IDF :  0.0
# Word :  street TF-IDF :  0.0
# Word :  streets TF-IDF :  0.0
# Word :  summer TF-IDF :  0.0
# Word :  sun TF-IDF :  0.045905371073525894
# Word :  sunlight TF-IDF :  0.0
# Word :  surround TF-IDF :  0.0
# Word :  surrounds TF-IDF :  0.03886227480284923
# Word :  sways TF-IDF :  0.03886227480284923
# Word :  symphony TF-IDF :  0.029555761680312927
# Word :  table TF-IDF :  0.0
# Word :  talents TF-IDF :  0.0
# Word :  tall TF-IDF :  0.0
# Word :  tapestry TF-IDF :  0.0
# Word :  taste TF-IDF :  0.029555761680312927
# Word :  tempting TF-IDF :  0.022952685536762947
# Word :  that TF-IDF :  0.022952685536762947
# Word :  the TF-IDF :  0.7344859371764143
# Word :  their TF-IDF :  0.16066879875734064
# Word :  thoughts TF-IDF :  0.0
# Word :  thread TF-IDF :  0.0
# Word :  through TF-IDF :  0.045905371073525894
# Word :  throughout TF-IDF :  0.03886227480284923
# Word :  to TF-IDF :  0.06885805661028885
# Word :  touch TF-IDF :  0.03886227480284923
# Word :  tranquility TF-IDF :  0.029555761680312927
# Word :  trees TF-IDF :  0.022952685536762947
# Word :  turning TF-IDF :  0.03886227480284923
# Word :  twinkle TF-IDF :  0.022952685536762947
# Word :  unfold TF-IDF :  0.0
# Word :  unique TF-IDF :  0.0
# Word :  upon TF-IDF :  0.03886227480284923
# Word :  urban TF-IDF :  0.0
# Word :  valley TF-IDF :  0.0
# Word :  vegetables TF-IDF :  0.03886227480284923
# Word :  velvety TF-IDF :  0.03886227480284923
# Word :  vendors TF-IDF :  0.03886227480284923
# Word :  vibrant TF-IDF :  0.045905371073525894
# Word :  wafts TF-IDF :  0.029555761680312927
# Word :  walk TF-IDF :  0.0
# Word :  walks TF-IDF :  0.0
# Word :  warm TF-IDF :  0.029555761680312927
# Word :  warms TF-IDF :  0.0
# Word :  warmth TF-IDF :  0.03886227480284923
# Word :  watch TF-IDF :  0.03886227480284923
# Word :  waves TF-IDF :  0.029555761680312927
# Word :  way TF-IDF :  0.0
# Word :  weaves TF-IDF :  0.0
# Word :  west TF-IDF :  0.0
# Word :  while TF-IDF :  0.029555761680312927
# Word :  wildflowers TF-IDF :  0.03886227480284923
# Word :  wind TF-IDF :  0.03886227480284923
# Word :  with TF-IDF :  0.09181074214705179
# Word :  wonder TF-IDF :  0.029555761680312927
# Word :  wonders TF-IDF :  0.0
# Word :  work TF-IDF :  0.03886227480284923
# Word :  world TF-IDF :  0.022952685536762947
# Word :  worlds TF-IDF :  0.0
# Word :  worth TF-IDF :  0.03886227480284923
# Word :  woven TF-IDF :  0.0
# Word :  you TF-IDF :  0.022952685536762947
# Document :  The majestic mountains rise tall against the clear blue sky, their peaks capped with snow. The sound of a babbling brook fills the air, as it weaves its way through the lush green valley. A deer gracefully leaps across the meadow, its coat shimmering in the sunlight. The scent of pine trees permeates the forest, creating a refreshing aroma.
#
# In a cozy cottage nestled by the lakeside, a crackling fireplace warms the room. The soft glow of candlelight illuminates the space, creating a peaceful ambiance. The aroma of freshly baked apple pie fills the kitchen, enticing everyone with its delicious scent. Family and friends gather around the table, sharing laughter and stories.
#
# As the sun sets, painting the sky with hues of orange and pink, a sense of tranquility settles over the landscape. The stars twinkle brightly, creating a breathtaking canopy in the night sky. The moon casts a gentle glow, guiding the way for nocturnal creatures. Owls hoot in the distance, adding to the mystique of the night.
#
# In the city, bustling streets are filled with the rhythm of life. Neon lights illuminate the skyline, creating a vibrant display. People hurry along, immersed in their own worlds, while street performers captivate audiences with their talents. The aroma of diverse cuisines fills the air, tempting taste buds with a culinary adventure.
#
# Life is a tapestry of experiences, each thread woven with moments of joy, love, and discovery. From serene natural landscapes to vibrant urban landscapes, every corner of the world offers its own unique beauty. Embrace the wonders that surround you and let the journey unfold, filled with remarkable encounters and cherished memories.
#
#
# Word :  across TF-IDF :  0.02945595868757981
# Word :  activity TF-IDF :  0.0
# Word :  adding TF-IDF :  0.02945595868757981
# Word :  adventure TF-IDF :  0.022875179609742398
# Word :  after TF-IDF :  0.0
# Word :  against TF-IDF :  0.022875179609742398
# Word :  air TF-IDF :  0.045750359219484796
# Word :  alive TF-IDF :  0.0
# Word :  along TF-IDF :  0.02945595868757981
# Word :  ambiance TF-IDF :  0.02945595868757981
# Word :  among TF-IDF :  0.0
# Word :  an TF-IDF :  0.0
# Word :  and TF-IDF :  0.13725107765845437
# Word :  appears TF-IDF :  0.0
# Word :  apple TF-IDF :  0.03873104586103769
# Word :  are TF-IDF :  0.03873104586103769
# Word :  aroma TF-IDF :  0.06862553882922719
# Word :  around TF-IDF :  0.02945595868757981
# Word :  array TF-IDF :  0.0
# Word :  art TF-IDF :  0.0
# Word :  as TF-IDF :  0.045750359219484796
# Word :  atmosphere TF-IDF :  0.0
# Word :  attracting TF-IDF :  0.0
# Word :  audiences TF-IDF :  0.03873104586103769
# Word :  awakening TF-IDF :  0.0
# Word :  awe TF-IDF :  0.0
# Word :  babbling TF-IDF :  0.03873104586103769
# Word :  baked TF-IDF :  0.02945595868757981
# Word :  bakery TF-IDF :  0.0
# Word :  bargaining TF-IDF :  0.0
# Word :  baristas TF-IDF :  0.0
# Word :  bask TF-IDF :  0.0
# Word :  be TF-IDF :  0.0
# Word :  beach TF-IDF :  0.0
# Word :  beachgoers TF-IDF :  0.0
# Word :  beautiful TF-IDF :  0.0
# Word :  beauty TF-IDF :  0.022875179609742398
# Word :  bees TF-IDF :  0.0
# Word :  birds TF-IDF :  0.0
# Word :  blooming TF-IDF :  0.0
# Word :  blue TF-IDF :  0.02945595868757981
# Word :  bonfire TF-IDF :  0.0
# Word :  bread TF-IDF :  0.0
# Word :  breathtaking TF-IDF :  0.03873104586103769
# Word :  breeze TF-IDF :  0.0
# Word :  brewed TF-IDF :  0.0
# Word :  brightly TF-IDF :  0.02945595868757981
# Word :  bringing TF-IDF :  0.0
# Word :  brings TF-IDF :  0.0
# Word :  briskly TF-IDF :  0.0
# Word :  brook TF-IDF :  0.03873104586103769
# Word :  buds TF-IDF :  0.02945595868757981
# Word :  build TF-IDF :  0.0
# Word :  bustling TF-IDF :  0.022875179609742398
# Word :  butterflies TF-IDF :  0.0
# Word :  by TF-IDF :  0.03873104586103769
# Word :  cafe TF-IDF :  0.0
# Word :  candlelight TF-IDF :  0.03873104586103769
# Word :  canopy TF-IDF :  0.03873104586103769
# Word :  capped TF-IDF :  0.03873104586103769
# Word :  captivate TF-IDF :  0.03873104586103769
# Word :  casting TF-IDF :  0.0
# Word :  casts TF-IDF :  0.02945595868757981
# Word :  celestial TF-IDF :  0.0
# Word :  charm TF-IDF :  0.0
# Word :  chatter TF-IDF :  0.0
# Word :  cherish TF-IDF :  0.0
# Word :  cherished TF-IDF :  0.03873104586103769
# Word :  cherishing TF-IDF :  0.0
# Word :  children TF-IDF :  0.0
# Word :  chirp TF-IDF :  0.0
# Word :  cities TF-IDF :  0.0
# Word :  city TF-IDF :  0.02945595868757981
# Word :  clear TF-IDF :  0.02945595868757981
# Word :  coat TF-IDF :  0.03873104586103769
# Word :  coffee TF-IDF :  0.0
# Word :  colorful TF-IDF :  0.0
# Word :  colors TF-IDF :  0.0
# Word :  comes TF-IDF :  0.0
# Word :  company TF-IDF :  0.0
# Word :  conversations TF-IDF :  0.0
# Word :  corner TF-IDF :  0.03873104586103769
# Word :  cottage TF-IDF :  0.03873104586103769
# Word :  couple TF-IDF :  0.0
# Word :  cozy TF-IDF :  0.02945595868757981
# Word :  crackling TF-IDF :  0.03873104586103769
# Word :  craft TF-IDF :  0.0
# Word :  crash TF-IDF :  0.0
# Word :  creating TF-IDF :  0.09150071843896959
# Word :  creatures TF-IDF :  0.03873104586103769
# Word :  crickets TF-IDF :  0.0
# Word :  cuisines TF-IDF :  0.03873104586103769
# Word :  culinary TF-IDF :  0.03873104586103769
# Word :  dance TF-IDF :  0.0
# Word :  darkness TF-IDF :  0.0
# Word :  day TF-IDF :  0.0
# Word :  deer TF-IDF :  0.03873104586103769
# Word :  delicious TF-IDF :  0.03873104586103769
# Word :  discovery TF-IDF :  0.03873104586103769
# Word :  display TF-IDF :  0.02945595868757981
# Word :  distance TF-IDF :  0.02945595868757981
# Word :  diverse TF-IDF :  0.03873104586103769
# Word :  diversity TF-IDF :  0.0
# Word :  dreams TF-IDF :  0.0
# Word :  each TF-IDF :  0.022875179609742398
# Word :  earth TF-IDF :  0.0
# Word :  echoes TF-IDF :  0.0
# Word :  echoing TF-IDF :  0.0
# Word :  embrace TF-IDF :  0.022875179609742398
# Word :  encounters TF-IDF :  0.03873104586103769
# Word :  energy TF-IDF :  0.0
# Word :  enjoying TF-IDF :  0.0
# Word :  enticing TF-IDF :  0.02945595868757981
# Word :  every TF-IDF :  0.022875179609742398
# Word :  everyone TF-IDF :  0.03873104586103769
# Word :  experience TF-IDF :  0.0
# Word :  experiences TF-IDF :  0.02945595868757981
# Word :  falls TF-IDF :  0.0
# Word :  family TF-IDF :  0.03873104586103769
# Word :  feast TF-IDF :  0.0
# Word :  field TF-IDF :  0.0
# Word :  fill TF-IDF :  0.0
# Word :  filled TF-IDF :  0.045750359219484796
# Word :  filling TF-IDF :  0.0
# Word :  fills TF-IDF :  0.06862553882922719
# Word :  find TF-IDF :  0.0
# Word :  fireflies TF-IDF :  0.0
# Word :  fireplace TF-IDF :  0.03873104586103769
# Word :  flight TF-IDF :  0.0
# Word :  flowers TF-IDF :  0.0
# Word :  for TF-IDF :  0.02945595868757981
# Word :  forest TF-IDF :  0.03873104586103769
# Word :  freshly TF-IDF :  0.022875179609742398
# Word :  friendly TF-IDF :  0.0
# Word :  friends TF-IDF :  0.02945595868757981
# Word :  from TF-IDF :  0.022875179609742398
# Word :  fruits TF-IDF :  0.0
# Word :  garden TF-IDF :  0.0
# Word :  gather TF-IDF :  0.02945595868757981
# Word :  gentle TF-IDF :  0.022875179609742398
# Word :  glow TF-IDF :  0.045750359219484796
# Word :  graceful TF-IDF :  0.0
# Word :  gracefully TF-IDF :  0.02945595868757981
# Word :  green TF-IDF :  0.03873104586103769
# Word :  guiding TF-IDF :  0.03873104586103769
# Word :  hand TF-IDF :  0.0
# Word :  happily TF-IDF :  0.0
# Word :  happiness TF-IDF :  0.0
# Word :  heat TF-IDF :  0.0
# Word :  holds TF-IDF :  0.0
# Word :  hoot TF-IDF :  0.02945595868757981
# Word :  horizon TF-IDF :  0.0
# Word :  hub TF-IDF :  0.0
# Word :  hues TF-IDF :  0.02945595868757981
# Word :  hurry TF-IDF :  0.03873104586103769
# Word :  illuminate TF-IDF :  0.03873104586103769
# Word :  illuminates TF-IDF :  0.03873104586103769
# Word :  illuminating TF-IDF :  0.0
# Word :  immersed TF-IDF :  0.02945595868757981
# Word :  in TF-IDF :  0.13725107765845437
# Word :  inspiring TF-IDF :  0.0
# Word :  into TF-IDF :  0.0
# Word :  intricate TF-IDF :  0.0
# Word :  is TF-IDF :  0.022875179609742398
# Word :  it TF-IDF :  0.03873104586103769
# Word :  its TF-IDF :  0.11782383475031924
# Word :  journey TF-IDF :  0.022875179609742398
# Word :  joy TF-IDF :  0.022875179609742398
# Word :  kitchen TF-IDF :  0.03873104586103769
# Word :  lakeside TF-IDF :  0.03873104586103769
# Word :  landscape TF-IDF :  0.02945595868757981
# Word :  landscapes TF-IDF :  0.07746209172207538
# Word :  late TF-IDF :  0.0
# Word :  latte TF-IDF :  0.0
# Word :  laughter TF-IDF :  0.022875179609742398
# Word :  leaps TF-IDF :  0.03873104586103769
# Word :  leaves TF-IDF :  0.0
# Word :  let TF-IDF :  0.02945595868757981
# Word :  life TF-IDF :  0.045750359219484796
# Word :  light TF-IDF :  0.0
# Word :  lights TF-IDF :  0.02945595868757981
# Word :  little TF-IDF :  0.0
# Word :  lively TF-IDF :  0.0
# Word :  love TF-IDF :  0.02945595868757981
# Word :  lush TF-IDF :  0.03873104586103769
# Word :  magic TF-IDF :  0.0
# Word :  magical TF-IDF :  0.0
# Word :  majestic TF-IDF :  0.03873104586103769
# Word :  market TF-IDF :  0.0
# Word :  meadow TF-IDF :  0.03873104586103769
# Word :  melodic TF-IDF :  0.0
# Word :  melodious TF-IDF :  0.0
# Word :  melody TF-IDF :  0.0
# Word :  memories TF-IDF :  0.03873104586103769
# Word :  mesmerizing TF-IDF :  0.0
# Word :  moments TF-IDF :  0.022875179609742398
# Word :  moon TF-IDF :  0.02945595868757981
# Word :  moonlit TF-IDF :  0.0
# Word :  mountains TF-IDF :  0.03873104586103769
# Word :  mystique TF-IDF :  0.03873104586103769
# Word :  natural TF-IDF :  0.03873104586103769
# Word :  nature TF-IDF :  0.0
# Word :  nearby TF-IDF :  0.0
# Word :  neon TF-IDF :  0.03873104586103769
# Word :  nestled TF-IDF :  0.03873104586103769
# Word :  new TF-IDF :  0.0
# Word :  night TF-IDF :  0.045750359219484796
# Word :  nocturnal TF-IDF :  0.03873104586103769
# Word :  of TF-IDF :  0.27450215531690875
# Word :  offers TF-IDF :  0.03873104586103769
# Word :  on TF-IDF :  0.0
# Word :  open TF-IDF :  0.0
# Word :  opportunities TF-IDF :  0.0
# Word :  orange TF-IDF :  0.03873104586103769
# Word :  other TF-IDF :  0.0
# Word :  over TF-IDF :  0.03873104586103769
# Word :  overhead TF-IDF :  0.0
# Word :  owls TF-IDF :  0.02945595868757981
# Word :  own TF-IDF :  0.045750359219484796
# Word :  painting TF-IDF :  0.022875179609742398
# Word :  park TF-IDF :  0.0
# Word :  passersby TF-IDF :  0.0
# Word :  path TF-IDF :  0.0
# Word :  patrons TF-IDF :  0.0
# Word :  peaceful TF-IDF :  0.03873104586103769
# Word :  peaks TF-IDF :  0.03873104586103769
# Word :  people TF-IDF :  0.02945595868757981
# Word :  performers TF-IDF :  0.03873104586103769
# Word :  permeates TF-IDF :  0.03873104586103769
# Word :  pie TF-IDF :  0.03873104586103769
# Word :  pine TF-IDF :  0.03873104586103769
# Word :  pink TF-IDF :  0.03873104586103769
# Word :  play TF-IDF :  0.0
# Word :  pleasures TF-IDF :  0.0
# Word :  quaint TF-IDF :  0.0
# Word :  rain TF-IDF :  0.0
# Word :  rainbow TF-IDF :  0.0
# Word :  rays TF-IDF :  0.0
# Word :  refreshing TF-IDF :  0.03873104586103769
# Word :  relaxation TF-IDF :  0.0
# Word :  relief TF-IDF :  0.0
# Word :  remarkable TF-IDF :  0.03873104586103769
# Word :  rhythm TF-IDF :  0.02945595868757981
# Word :  rise TF-IDF :  0.03873104586103769
# Word :  romantic TF-IDF :  0.0
# Word :  room TF-IDF :  0.03873104586103769
# Word :  rustles TF-IDF :  0.0
# Word :  sandcastles TF-IDF :  0.0
# Word :  sandy TF-IDF :  0.0
# Word :  savor TF-IDF :  0.0
# Word :  scent TF-IDF :  0.045750359219484796
# Word :  seagulls TF-IDF :  0.0
# Word :  sense TF-IDF :  0.03873104586103769
# Word :  senses TF-IDF :  0.0
# Word :  serenade TF-IDF :  0.0
# Word :  serene TF-IDF :  0.03873104586103769
# Word :  sets TF-IDF :  0.02945595868757981
# Word :  settles TF-IDF :  0.03873104586103769
# Word :  sharing TF-IDF :  0.02945595868757981
# Word :  shimmering TF-IDF :  0.03873104586103769
# Word :  shines TF-IDF :  0.0
# Word :  shore TF-IDF :  0.0
# Word :  simple TF-IDF :  0.0
# Word :  sip TF-IDF :  0.0
# Word :  skillfully TF-IDF :  0.0
# Word :  skin TF-IDF :  0.0
# Word :  sky TF-IDF :  0.06862553882922719
# Word :  skyline TF-IDF :  0.03873104586103769
# Word :  smell TF-IDF :  0.0
# Word :  snow TF-IDF :  0.03873104586103769
# Word :  soar TF-IDF :  0.0
# Word :  soft TF-IDF :  0.02945595868757981
# Word :  songs TF-IDF :  0.0
# Word :  soothing TF-IDF :  0.0
# Word :  sound TF-IDF :  0.02945595868757981
# Word :  sounds TF-IDF :  0.0
# Word :  space TF-IDF :  0.022875179609742398
# Word :  spices TF-IDF :  0.0
# Word :  stars TF-IDF :  0.022875179609742398
# Word :  stories TF-IDF :  0.02945595868757981
# Word :  street TF-IDF :  0.03873104586103769
# Word :  streets TF-IDF :  0.02945595868757981
# Word :  summer TF-IDF :  0.0
# Word :  sun TF-IDF :  0.022875179609742398
# Word :  sunlight TF-IDF :  0.03873104586103769
# Word :  surround TF-IDF :  0.02945595868757981
# Word :  surrounds TF-IDF :  0.0
# Word :  sways TF-IDF :  0.0
# Word :  symphony TF-IDF :  0.0
# Word :  table TF-IDF :  0.03873104586103769
# Word :  talents TF-IDF :  0.03873104586103769
# Word :  tall TF-IDF :  0.03873104586103769
# Word :  tapestry TF-IDF :  0.03873104586103769
# Word :  taste TF-IDF :  0.02945595868757981
# Word :  tempting TF-IDF :  0.022875179609742398
# Word :  that TF-IDF :  0.022875179609742398
# Word :  the TF-IDF :  0.7777561067312415
# Word :  their TF-IDF :  0.06862553882922719
# Word :  thoughts TF-IDF :  0.0
# Word :  thread TF-IDF :  0.03873104586103769
# Word :  through TF-IDF :  0.022875179609742398
# Word :  throughout TF-IDF :  0.0
# Word :  to TF-IDF :  0.045750359219484796
# Word :  touch TF-IDF :  0.0
# Word :  tranquility TF-IDF :  0.02945595868757981
# Word :  trees TF-IDF :  0.022875179609742398
# Word :  turning TF-IDF :  0.0
# Word :  twinkle TF-IDF :  0.022875179609742398
# Word :  unfold TF-IDF :  0.03873104586103769
# Word :  unique TF-IDF :  0.03873104586103769
# Word :  upon TF-IDF :  0.0
# Word :  urban TF-IDF :  0.03873104586103769
# Word :  valley TF-IDF :  0.03873104586103769
# Word :  vegetables TF-IDF :  0.0
# Word :  velvety TF-IDF :  0.0
# Word :  vendors TF-IDF :  0.0
# Word :  vibrant TF-IDF :  0.045750359219484796
# Word :  wafts TF-IDF :  0.0
# Word :  walk TF-IDF :  0.0
# Word :  walks TF-IDF :  0.0
# Word :  warm TF-IDF :  0.0
# Word :  warms TF-IDF :  0.03873104586103769
# Word :  warmth TF-IDF :  0.0
# Word :  watch TF-IDF :  0.0
# Word :  waves TF-IDF :  0.0
# Word :  way TF-IDF :  0.07746209172207538
# Word :  weaves TF-IDF :  0.03873104586103769
# Word :  west TF-IDF :  0.0
# Word :  while TF-IDF :  0.02945595868757981
# Word :  wildflowers TF-IDF :  0.0
# Word :  wind TF-IDF :  0.0
# Word :  with TF-IDF :  0.18300143687793918
# Word :  wonder TF-IDF :  0.0
# Word :  wonders TF-IDF :  0.03873104586103769
# Word :  work TF-IDF :  0.0
# Word :  world TF-IDF :  0.022875179609742398
# Word :  worlds TF-IDF :  0.03873104586103769
# Word :  worth TF-IDF :  0.0
# Word :  woven TF-IDF :  0.03873104586103769
# Word :  you TF-IDF :  0.022875179609742398

# %%
tf={}
for word in filtered_tokens[0]:
    if word in tf:
        tf[word]+=1
    else:
        tf[word]=1

word_counts=len(filtered_tokens)

for word in tf:
    tf[word]=tf[word]/word_counts
    print("word : ",word ," : ",tf[word])
# Out:
# word :  sun  :  0.3333333333333333
# word :  sets  :  0.3333333333333333
# word :  west  :  0.3333333333333333
# word :  ,  :  5.666666666666667
# word :  casting  :  0.3333333333333333
# word :  warm  :  0.3333333333333333
# word :  glow  :  0.3333333333333333
# word :  across  :  0.3333333333333333
# word :  horizon  :  0.3333333333333333
# word :  .  :  5.666666666666667
# word :  Birds  :  0.3333333333333333
# word :  chirp  :  0.3333333333333333
# word :  happily  :  0.3333333333333333
# word :  trees  :  0.3333333333333333
# word :  creating  :  1.0
# word :  melodious  :  0.3333333333333333
# word :  symphony  :  0.3333333333333333
# word :  smell  :  0.3333333333333333
# word :  freshly  :  0.6666666666666666
# word :  brewed  :  0.3333333333333333
# word :  coffee  :  0.3333333333333333
# word :  fills  :  0.6666666666666666
# word :  air  :  0.3333333333333333
# word :  awakening  :  0.3333333333333333
# word :  senses  :  0.3333333333333333
# word :  People  :  0.3333333333333333
# word :  walk  :  0.3333333333333333
# word :  briskly  :  0.3333333333333333
# word :  bustling  :  0.3333333333333333
# word :  streets  :  0.3333333333333333
# word :  immersed  :  0.3333333333333333
# word :  thoughts  :  0.3333333333333333
# word :  Children  :  0.3333333333333333
# word :  play  :  0.3333333333333333
# word :  park  :  0.3333333333333333
# word :  laughter  :  0.6666666666666666
# word :  echoing  :  0.3333333333333333
# word :  open  :  0.3333333333333333
# word :  space  :  0.3333333333333333
# word :  gentle  :  0.3333333333333333
# word :  breeze  :  0.3333333333333333
# word :  rustles  :  0.3333333333333333
# word :  leaves  :  0.3333333333333333
# word :  bringing  :  0.3333333333333333
# word :  relief  :  0.3333333333333333
# word :  summer  :  0.3333333333333333
# word :  heat  :  0.3333333333333333
# word :  rainbow  :  0.3333333333333333
# word :  appears  :  0.3333333333333333
# word :  rain  :  0.3333333333333333
# word :  painting  :  0.3333333333333333
# word :  sky  :  0.6666666666666666
# word :  vibrant  :  0.3333333333333333
# word :  colors  :  0.3333333333333333
# word :  waves  :  0.3333333333333333
# word :  crash  :  0.3333333333333333
# word :  shore  :  0.3333333333333333
# word :  soothing  :  0.3333333333333333
# word :  rhythm  :  0.3333333333333333
# word :  aroma  :  0.3333333333333333
# word :  baked  :  0.3333333333333333
# word :  bread  :  0.3333333333333333
# word :  wafts  :  0.3333333333333333
# word :  nearby  :  0.3333333333333333
# word :  bakery  :  0.3333333333333333
# word :  tempting  :  0.3333333333333333
# word :  passersby  :  0.3333333333333333
# word :  Friends  :  0.3333333333333333
# word :  gather  :  0.3333333333333333
# word :  around  :  0.3333333333333333
# word :  bonfire  :  0.3333333333333333
# word :  sharing  :  0.3333333333333333
# word :  stories  :  0.3333333333333333
# word :  late  :  0.3333333333333333
# word :  night  :  1.0
# word :  city  :  0.3333333333333333
# word :  comes  :  0.3333333333333333
# word :  alive  :  0.3333333333333333
# word :  lights  :  0.3333333333333333
# word :  falls  :  0.3333333333333333
# word :  magical  :  0.3333333333333333
# word :  atmosphere  :  0.3333333333333333
# word :  Stars  :  0.3333333333333333
# word :  twinkle  :  0.3333333333333333
# word :  clear  :  0.3333333333333333
# word :  inspiring  :  0.3333333333333333
# word :  dreams  :  0.3333333333333333
# word :  wonder  :  0.3333333333333333
# word :  scent  :  0.3333333333333333
# word :  blooming  :  0.3333333333333333
# word :  flowers  :  0.3333333333333333
# word :  garden  :  0.3333333333333333
# word :  attracting  :  0.3333333333333333
# word :  bees  :  0.3333333333333333
# word :  butterflies  :  0.3333333333333333
# word :  couple  :  0.3333333333333333
# word :  walks  :  0.3333333333333333
# word :  hand  :  0.6666666666666666
# word :  along  :  0.3333333333333333
# word :  moonlit  :  0.3333333333333333
# word :  path  :  0.3333333333333333
# word :  enjoying  :  0.3333333333333333
# word :  's  :  0.3333333333333333
# word :  company  :  0.3333333333333333
# word :  Life  :  0.3333333333333333
# word :  beautiful  :  0.3333333333333333
# word :  journey  :  0.3333333333333333
# word :  filled  :  0.3333333333333333
# word :  moments  :  0.3333333333333333
# word :  joy  :  0.3333333333333333
# word :  love  :  0.3333333333333333
# word :  adventure  :  0.3333333333333333
# word :  Every  :  0.3333333333333333
# word :  day  :  0.3333333333333333
# word :  brings  :  0.3333333333333333
# word :  new  :  0.3333333333333333
# word :  opportunities  :  0.3333333333333333
# word :  experiences  :  0.3333333333333333
# word :  cherish  :  0.3333333333333333
# word :  Embrace  :  0.3333333333333333
# word :  beauty  :  0.3333333333333333
# word :  world  :  0.3333333333333333
# word :  find  :  0.3333333333333333
# word :  happiness  :  0.3333333333333333
# word :  simple  :  0.3333333333333333
# word :  pleasures  :  0.3333333333333333
# word :  surround  :  0.3333333333333333

# %%
import numpy as np
idf={}

for word in filtered_tokens[1]:
    for doc in filtered_tokens:
        if(word in filtered_tokens[doc]):
            if word in idf:
                idf[word]+=1
            else:
                idf[word]=1
    idf[word]=np.log(3/idf[word])
    print("IDF for word : ",word," ",idf[word])
# Out:
# IDF for word :  gentle   0.0
# IDF for word :  breeze   0.4054651081081644
# IDF for word :  rustles   0.4054651081081644
# IDF for word :  leaves   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  creating   0.0
# IDF for word :  soothing   0.4054651081081644
# IDF for word :  melody   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  Birds   0.4054651081081644
# IDF for word :  chirp   0.4054651081081644
# IDF for word :  distance   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  melodic   1.0986122886681098
# IDF for word :  songs   1.0986122886681098
# IDF for word :  filling   1.0986122886681098
# IDF for word :  air   0.0
# IDF for word :  .   0.0
# IDF for word :  field   1.0986122886681098
# IDF for word :  colorful   1.0986122886681098
# IDF for word :  wildflowers   1.0986122886681098
# IDF for word :  sways   1.0986122886681098
# IDF for word :  gracefully   0.4054651081081644
# IDF for word :  wind   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  painting   0.0
# IDF for word :  landscape   0.4054651081081644
# IDF for word :  vibrant   0.0
# IDF for word :  hues   0.4054651081081644
# IDF for word :  .   0.0
# IDF for word :  sun   0.0
# IDF for word :  shines   1.0986122886681098
# IDF for word :  brightly   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  casting   0.4054651081081644
# IDF for word :  warm   0.4054651081081644
# IDF for word :  rays   1.0986122886681098
# IDF for word :  upon   1.0986122886681098
# IDF for word :  earth   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  quaint   1.0986122886681098
# IDF for word :  little   1.0986122886681098
# IDF for word :  cafe   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  aroma   0.0
# IDF for word :  freshly   0.0
# IDF for word :  brewed   0.4054651081081644
# IDF for word :  coffee   0.4054651081081644
# IDF for word :  fills   0.0
# IDF for word :  air   0.0
# IDF for word :  ,   0.0
# IDF for word :  enticing   0.4054651081081644
# IDF for word :  passersby   0.4054651081081644
# IDF for word :  .   0.0
# IDF for word :  Baristas   1.0986122886681098
# IDF for word :  skillfully   1.0986122886681098
# IDF for word :  craft   1.0986122886681098
# IDF for word :  intricate   1.0986122886681098
# IDF for word :  latte   1.0986122886681098
# IDF for word :  art   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  turning   1.0986122886681098
# IDF for word :  coffee   0.22086901166346848
# IDF for word :  work   1.0986122886681098
# IDF for word :  art   0.3573359772930943
# IDF for word :  .   0.0
# IDF for word :  sound   0.4054651081081644
# IDF for word :  friendly   1.0986122886681098
# IDF for word :  chatter   1.0986122886681098
# IDF for word :  laughter   0.0
# IDF for word :  echoes   1.0986122886681098
# IDF for word :  throughout   1.0986122886681098
# IDF for word :  cozy   0.4054651081081644
# IDF for word :  space   0.0
# IDF for word :  .   0.0
# IDF for word :  Patrons   1.0986122886681098
# IDF for word :  savor   1.0986122886681098
# IDF for word :  sip   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  enjoying   0.4054651081081644
# IDF for word :  moments   0.0
# IDF for word :  relaxation   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  sandy   1.0986122886681098
# IDF for word :  beach   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  waves   0.4054651081081644
# IDF for word :  crash   0.4054651081081644
# IDF for word :  shore   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  creating   0.0
# IDF for word :  symphony   0.4054651081081644
# IDF for word :  sounds   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  Children   0.4054651081081644
# IDF for word :  build   1.0986122886681098
# IDF for word :  sandcastles   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  laughter   0.0
# IDF for word :  filling   0.3573359772930943
# IDF for word :  air   0.0
# IDF for word :  joy   0.0
# IDF for word :  .   0.0
# IDF for word :  Seagulls   1.0986122886681098
# IDF for word :  soar   1.0986122886681098
# IDF for word :  overhead   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  graceful   1.0986122886681098
# IDF for word :  flight   1.0986122886681098
# IDF for word :  blue   0.4054651081081644
# IDF for word :  sky   0.0
# IDF for word :  mesmerizing   1.0986122886681098
# IDF for word :  watch   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  Beachgoers   1.0986122886681098
# IDF for word :  bask   1.0986122886681098
# IDF for word :  sun   0.0
# IDF for word :  ,   0.0
# IDF for word :  enjoying   0.22086901166346848
# IDF for word :  warmth   1.0986122886681098
# IDF for word :  skin   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  bustling   0.0
# IDF for word :  market   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  vendors   1.0986122886681098
# IDF for word :  display   0.4054651081081644
# IDF for word :  colorful   0.3573359772930943
# IDF for word :  array   1.0986122886681098
# IDF for word :  fruits   1.0986122886681098
# IDF for word :  vegetables   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  scent   0.0
# IDF for word :  spices   1.0986122886681098
# IDF for word :  wafts   0.4054651081081644
# IDF for word :  air   0.0
# IDF for word :  ,   0.0
# IDF for word :  tempting   0.0
# IDF for word :  taste   0.4054651081081644
# IDF for word :  buds   0.4054651081081644
# IDF for word :  .   0.0
# IDF for word :  Bargaining   1.0986122886681098
# IDF for word :  lively   1.0986122886681098
# IDF for word :  conversations   1.0986122886681098
# IDF for word :  fill   1.0986122886681098
# IDF for word :  atmosphere   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  creating   0.0
# IDF for word :  lively   0.3573359772930943
# IDF for word :  vibrant   0.0
# IDF for word :  ambiance   0.4054651081081644
# IDF for word :  .   0.0
# IDF for word :  market   0.3573359772930943
# IDF for word :  hub   1.0986122886681098
# IDF for word :  activity   1.0986122886681098
# IDF for word :  feast   1.0986122886681098
# IDF for word :  senses   0.4054651081081644
# IDF for word :  .   0.0
# IDF for word :  night   0.0
# IDF for word :  falls   0.4054651081081644
# IDF for word :  ,   0.0
# IDF for word :  stars   0.4054651081081644
# IDF for word :  twinkle   0.0
# IDF for word :  velvety   1.0986122886681098
# IDF for word :  sky   0.0
# IDF for word :  ,   0.0
# IDF for word :  illuminating   1.0986122886681098
# IDF for word :  world   0.0
# IDF for word :  celestial   1.0986122886681098
# IDF for word :  glow   0.0
# IDF for word :  .   0.0
# IDF for word :  moon   0.4054651081081644
# IDF for word :  casts   0.4054651081081644
# IDF for word :  gentle   0.0
# IDF for word :  light   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  creating   0.0
# IDF for word :  romantic   1.0986122886681098
# IDF for word :  atmosphere   0.22086901166346848
# IDF for word :  .   0.0
# IDF for word :  Fireflies   1.0986122886681098
# IDF for word :  dance   1.0986122886681098
# IDF for word :  among   1.0986122886681098
# IDF for word :  trees   0.0
# IDF for word :  ,   0.0
# IDF for word :  soft   0.4054651081081644
# IDF for word :  glow   0.0
# IDF for word :  adding   0.4054651081081644
# IDF for word :  touch   1.0986122886681098
# IDF for word :  magic   1.0986122886681098
# IDF for word :  night   0.0
# IDF for word :  .   0.0
# IDF for word :  Night   1.0986122886681098
# IDF for word :  owls   1.0986122886681098
# IDF for word :  hoot   0.4054651081081644
# IDF for word :  distance   0.22086901166346848
# IDF for word :  ,   0.0
# IDF for word :  crickets   1.0986122886681098
# IDF for word :  serenade   1.0986122886681098
# IDF for word :  darkness   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  Life   0.0
# IDF for word :  beautiful   0.4054651081081644
# IDF for word :  journey   0.0
# IDF for word :  ,   0.0
# IDF for word :  filled   0.0
# IDF for word :  moments   0.0
# IDF for word :  wonder   0.4054651081081644
# IDF for word :  awe   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  tranquility   0.4054651081081644
# IDF for word :  nature   1.0986122886681098
# IDF for word :  energy   1.0986122886681098
# IDF for word :  bustling   0.0
# IDF for word :  cities   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  every   0.4054651081081644
# IDF for word :  experience   1.0986122886681098
# IDF for word :  holds   1.0986122886681098
# IDF for word :  charm   1.0986122886681098
# IDF for word :  .   0.0
# IDF for word :  Embrace   0.0
# IDF for word :  diversity   1.0986122886681098
# IDF for word :  beauty   0.0
# IDF for word :  surrounds   1.0986122886681098
# IDF for word :  ,   0.0
# IDF for word :  let   0.4054651081081644
# IDF for word :  day   0.4054651081081644
# IDF for word :  adventure   0.0
# IDF for word :  worth   1.0986122886681098
# IDF for word :  cherishing   1.0986122886681098
# IDF for word :  .   0.0
